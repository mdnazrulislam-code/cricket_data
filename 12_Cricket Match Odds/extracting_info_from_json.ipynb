# %% [markdown]
# # Cricket Match odds

# %%
import numpy as np
import pandas as pd
import json
import http.client
import time  

# List of match IDs
match_ids = [
    13265827, 13265828, 13265829, 13265830, 13265831, 13265832, 13265833, 
    13265834, 13265836, 13265837, 13265838, 13265840, 13558575, 13558576, 13569002
]

# API connection setup
conn = http.client.HTTPSConnection("allsportsapi2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "693b14936cmshb4229d5afd9d447p186b67jsn499928bbef0a",
    'x-rapidapi-host': "allsportsapi2.p.rapidapi.com"
}

# Parent dictionary to store all match data
parent_json = {}

# Loop through each match ID
for match_id in match_ids:
    try:
        # Make API request
        conn.request("GET", f"/api/cricket/match/{match_id}/odds", headers=headers)
        res = conn.getresponse()
        data = res.read()
        
        # Convert response to JSON
        data_json = json.loads(data.decode("utf-8"))
        
        # Store JSON in the parent dictionary with match_id as key
        parent_json[f"match_odds_{match_id}"] = data_json

        print(f"Data collected for Match ID {match_id}")

    except Exception as e:
        print(f"Error fetching data for Match ID {match_id}: {e}")

    time.sleep(1)  # Optional: Delay to prevent rate limits

# Save all match data in a single JSON file
with open("all_match_odds_data.json", "w", encoding="utf-8") as f:
    json.dump(parent_json, f, indent=4)

print("All match data saved in all_match_odds_data.json")
# Out:
# Data collected for Match ID 13265827
# Data collected for Match ID 13265828
# Data collected for Match ID 13265829
# Data collected for Match ID 13265830
# Data collected for Match ID 13265831
# Data collected for Match ID 13265832
# Data collected for Match ID 13265833
# Data collected for Match ID 13265834
# Data collected for Match ID 13265836
# Data collected for Match ID 13265837
# Data collected for Match ID 13265838
# Data collected for Match ID 13265840
# Data collected for Match ID 13558575
# Data collected for Match ID 13558576
# Data collected for Match ID 13569002
# All match data saved in all_match_odds_data.json

# %% [markdown]
# ## Loading Json file

# %%
with open("all_match_odds_data.json", "r", encoding="utf-8") as f:
    match_odds_detail = json.load(f)
match_odds_detail
# Out:
# {'match_odds_13265827': {'markets': [{'sourceId': 169647244,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 169647244,
#     'suspended': False,
#     'id': 1984214393,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '67/100',
#       'sourceId': 96527027,
#       'name': '1',
#       'winning': False,
#       'change': -1},
#      {'initialFractionalValue': '1/1',
#       'fractionalValue': '6/5',
#       'sourceId': 96527028,
#       'name': '2',
#       'winning': True,
#       'change': 1}]},
#    {'sourceId': 169647244,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 169647244,
#     'suspended': False,
#     'id': 1984252581,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96557230,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96557233,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 169647244,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 169647244,
#     'suspended': False,
#     'id': 1984252583,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '8/11',
#       'fractionalValue': '4/5',
#       'sourceId': 96557538,
#       'name': 'Yes',
#       'change': 1},
#      {'initialFractionalValue': '1/1',
#       'fractionalValue': '10/11',
#       'sourceId': 96557548,
#       'name': 'No',
#       'change': -1}]},
#    {'sourceId': 169647244,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 169647244,
#     'suspended': False,
#     'id': 1984252582,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '20/21',
#       'fractionalValue': '5/4',
#       'sourceId': 96557183,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '6/1',
#       'sourceId': 96557186,
#       'name': 'X',
#       'change': 0},
#      {'initialFractionalValue': '6/5',
#       'fractionalValue': '10/11',
#       'sourceId': 96557189,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 169647244,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 169647244,
#     'suspended': False,
#     'id': 1984252584,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/40',
#       'fractionalValue': '1/40',
#       'sourceId': 96557450,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '16/1',
#       'fractionalValue': '16/1',
#       'sourceId': 96557475,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265827},
#  'match_odds_13265828': {'markets': [{'sourceId': 169647245,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 169647245,
#     'suspended': False,
#     'id': 1984214394,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '6/1',
#       'fractionalValue': '8/1',
#       'sourceId': 96527029,
#       'name': '1',
#       'winning': False,
#       'change': 1},
#      {'initialFractionalValue': '1/10',
#       'fractionalValue': '7/100',
#       'sourceId': 96527030,
#       'name': '2',
#       'winning': True,
#       'change': -1}]},
#    {'sourceId': 169647245,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 169647245,
#     'suspended': False,
#     'id': 1984252600,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96553304,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96553307,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 169647245,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 169647245,
#     'suspended': False,
#     'id': 1984252602,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '5/4',
#       'fractionalValue': '1/1',
#       'sourceId': 96553529,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '4/7',
#       'fractionalValue': '8/11',
#       'sourceId': 96553531,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 169647245,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 169647245,
#     'suspended': False,
#     'id': 1984252601,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/3',
#       'fractionalValue': '11/5',
#       'sourceId': 96553263,
#       'name': '1',
#       'change': -1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '6/1',
#       'sourceId': 96553272,
#       'name': 'X',
#       'change': 0},
#      {'initialFractionalValue': '4/11',
#       'fractionalValue': '8/15',
#       'sourceId': 96553276,
#       'name': '2',
#       'change': 1}]},
#    {'sourceId': 169647245,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 169647245,
#     'suspended': False,
#     'id': 1984252603,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/16',
#       'fractionalValue': '1/25',
#       'sourceId': 96553513,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '9/1',
#       'fractionalValue': '12/1',
#       'sourceId': 96553519,
#       'name': 'No',
#       'change': 1}]}],
#   'eventId': 13265828},
#  'match_odds_13265829': {'markets': [{'sourceId': 169647246,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 169647246,
#     'suspended': False,
#     'id': 1984244086,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '163/100',
#       'fractionalValue': '7/4',
#       'sourceId': 96527031,
#       'name': '1',
#       'winning': False,
#       'change': 1},
#      {'initialFractionalValue': '1/2',
#       'fractionalValue': '11/25',
#       'sourceId': 96527032,
#       'name': '2',
#       'winning': True,
#       'change': -1}]},
#    {'sourceId': 169647246,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 169647246,
#     'suspended': False,
#     'id': 1984289245,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96559651,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96559654,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 169647246,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 169647246,
#     'suspended': False,
#     'id': 1984289247,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '5/6',
#       'fractionalValue': '1/1',
#       'sourceId': 96559761,
#       'name': 'Yes',
#       'change': 1},
#      {'initialFractionalValue': '5/6',
#       'fractionalValue': '8/11',
#       'sourceId': 96559764,
#       'name': 'No',
#       'change': -1}]},
#    {'sourceId': 169647246,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 169647246,
#     'suspended': False,
#     'id': 1984289246,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '13/10',
#       'fractionalValue': '21/10',
#       'sourceId': 96559623,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '11/2',
#       'fractionalValue': '13/2',
#       'sourceId': 96559625,
#       'name': 'X',
#       'change': 1},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '8/15',
#       'sourceId': 96559627,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 169647246,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 169647246,
#     'suspended': False,
#     'id': 1984289248,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/33',
#       'fractionalValue': '1/25',
#       'sourceId': 96559739,
#       'name': 'Yes',
#       'change': 1},
#      {'initialFractionalValue': '14/1',
#       'fractionalValue': '12/1',
#       'sourceId': 96559742,
#       'name': 'No',
#       'change': -1}]},
#    {'sourceId': 169647246,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 169647246,
#     'suspended': False,
#     'id': 1988411782,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '40/1',
#       'fractionalValue': '40/1',
#       'sourceId': 96559839,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/250',
#       'fractionalValue': '1/250',
#       'sourceId': 96559841,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265829},
#  'match_odds_13265830': {'markets': [{'sourceId': 169647247,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 169647247,
#     'suspended': False,
#     'id': 1984244087,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '73/100',
#       'fractionalValue': '4/5',
#       'sourceId': 96527033,
#       'name': '1',
#       'winning': True,
#       'change': 1},
#      {'initialFractionalValue': '11/10',
#       'fractionalValue': '1/1',
#       'sourceId': 96527034,
#       'name': '2',
#       'winning': False,
#       'change': -1}]},
#    {'sourceId': 169647247,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 169647247,
#     'suspended': False,
#     'id': 1984647805,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96554438,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 96554441,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 169647247,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 169647247,
#     'suspended': False,
#     'id': 1984647807,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '5/6',
#       'fractionalValue': '4/6',
#       'sourceId': 96554526,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '5/6',
#       'fractionalValue': '11/10',
#       'sourceId': 96554527,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 169647247,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 169647247,
#     'suspended': False,
#     'id': 1984647806,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '11/10',
#       'sourceId': 96554424,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '13/2',
#       'sourceId': 96554425,
#       'name': 'X',
#       'change': 1},
#      {'initialFractionalValue': '13/10',
#       'fractionalValue': '1/1',
#       'sourceId': 96554426,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 169647247,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 169647247,
#     'suspended': False,
#     'id': 1984647808,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/33',
#       'fractionalValue': '1/50',
#       'sourceId': 96554512,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '14/1',
#       'fractionalValue': '18/1',
#       'sourceId': 96554514,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 169647247,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 169647247,
#     'suspended': False,
#     'id': 1988411838,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '40/1',
#       'fractionalValue': '40/1',
#       'sourceId': 96554594,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/250',
#       'fractionalValue': '1/250',
#       'sourceId': 96554596,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265830},
#  'match_odds_13265831': {'markets': [{'sourceId': 170179395,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170179395,
#     'suspended': False,
#     'id': 1988539933,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '2/1',
#       'fractionalValue': '11/5',
#       'sourceId': 164417099,
#       'name': '1',
#       'winning': False,
#       'change': 1},
#      {'initialFractionalValue': '2/5',
#       'fractionalValue': '9/25',
#       'sourceId': 164417104,
#       'name': '2',
#       'winning': True,
#       'change': -1}]},
#    {'sourceId': 170179395,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170179395,
#     'suspended': False,
#     'id': 1988593588,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 164471886,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 164471889,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170179395,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170179395,
#     'suspended': False,
#     'id': 1988593590,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '5/6',
#       'fractionalValue': '4/6',
#       'sourceId': 164471963,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '5/6',
#       'fractionalValue': '11/10',
#       'sourceId': 164471964,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170179395,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170179395,
#     'suspended': False,
#     'id': 1988593589,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '12/5',
#       'fractionalValue': '3/1',
#       'sourceId': 164471871,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '13/2',
#       'fractionalValue': '7/1',
#       'sourceId': 164471872,
#       'name': 'X',
#       'change': 1},
#      {'initialFractionalValue': '4/9',
#       'fractionalValue': '4/11',
#       'sourceId': 164471873,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170179395,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170179395,
#     'suspended': False,
#     'id': 1988593591,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/33',
#       'fractionalValue': '1/66',
#       'sourceId': 164471918,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '14/1',
#       'fractionalValue': '20/1',
#       'sourceId': 164471932,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170179395,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170179395,
#     'suspended': False,
#     'id': 1988593592,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '33/1',
#       'fractionalValue': '33/1',
#       'sourceId': 164471980,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/200',
#       'fractionalValue': '1/200',
#       'sourceId': 164471981,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265831},
#  'match_odds_13265832': {'markets': [{'sourceId': 170171312,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170171312,
#     'suspended': False,
#     'id': 1988583369,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/3',
#       'fractionalValue': '7/2',
#       'sourceId': 163478260,
#       'name': '1',
#       'winning': False,
#       'change': 1},
#      {'initialFractionalValue': '11/50',
#       'fractionalValue': '1/5',
#       'sourceId': 163478261,
#       'name': '2',
#       'winning': True,
#       'change': -1}]},
#    {'sourceId': 170171312,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170171312,
#     'suspended': False,
#     'id': 1988650654,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 163775787,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 163775788,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170171312,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170171312,
#     'suspended': False,
#     'id': 1988650656,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '11/10',
#       'fractionalValue': '4/5',
#       'sourceId': 163775803,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '4/6',
#       'fractionalValue': '10/11',
#       'sourceId': 163775804,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170171312,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170171312,
#     'suspended': False,
#     'id': 1988650655,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '7/4',
#       'fractionalValue': '2/1',
#       'sourceId': 163775781,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '6/1',
#       'sourceId': 163775782,
#       'name': 'X',
#       'change': 0},
#      {'initialFractionalValue': '4/6',
#       'fractionalValue': '4/7',
#       'sourceId': 163775784,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170171312,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170171312,
#     'suspended': False,
#     'id': 1988650657,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/25',
#       'fractionalValue': '1/40',
#       'sourceId': 163775799,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '12/1',
#       'fractionalValue': '16/1',
#       'sourceId': 163775800,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170171312,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170171312,
#     'suspended': False,
#     'id': 1988650658,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '40/1',
#       'fractionalValue': '40/1',
#       'sourceId': 163775819,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/250',
#       'fractionalValue': '1/250',
#       'sourceId': 163775820,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265832},
#  'match_odds_13265833': {'markets': [{'sourceId': 170279742,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170279742,
#     'suspended': False,
#     'id': 1990605956,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '73/100',
#       'fractionalValue': '31/50',
#       'sourceId': 178819807,
#       'name': '1',
#       'change': -1},
#      {'initialFractionalValue': '11/10',
#       'fractionalValue': '13/10',
#       'sourceId': 178819809,
#       'name': '2',
#       'change': 1}]},
#    {'sourceId': 170279742,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170279742,
#     'suspended': False,
#     'id': 1990690125,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 178931244,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 178931245,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170279742,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170279742,
#     'suspended': False,
#     'id': 1990690127,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '8/13',
#       'fractionalValue': '8/13',
#       'sourceId': 178931292,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '6/5',
#       'fractionalValue': '6/5',
#       'sourceId': 178931293,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170279742,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170279742,
#     'suspended': False,
#     'id': 1990690126,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '11/10',
#       'fractionalValue': '21/20',
#       'sourceId': 178931239,
#       'name': '1',
#       'change': -1},
#      {'initialFractionalValue': '13/2',
#       'fractionalValue': '6/1',
#       'sourceId': 178931240,
#       'name': 'X',
#       'change': -1},
#      {'initialFractionalValue': '20/21',
#       'fractionalValue': '11/10',
#       'sourceId': 178931241,
#       'name': '2',
#       'change': 1}]},
#    {'sourceId': 170279742,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170279742,
#     'suspended': False,
#     'id': 1990690128,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/80',
#       'fractionalValue': '1/80',
#       'sourceId': 178931278,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '22/1',
#       'fractionalValue': '22/1',
#       'sourceId': 178931288,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170279742,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170279742,
#     'suspended': False,
#     'id': 1990690129,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '40/1',
#       'fractionalValue': '40/1',
#       'sourceId': 178931310,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/250',
#       'fractionalValue': '1/250',
#       'sourceId': 178931311,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265833},
#  'match_odds_13265834': {'markets': [{'sourceId': 170280187,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170280187,
#     'suspended': False,
#     'id': 1990605957,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '5/2',
#       'fractionalValue': '11/4',
#       'sourceId': 178875760,
#       'name': '1',
#       'winning': True,
#       'change': 1},
#      {'initialFractionalValue': '3/10',
#       'fractionalValue': '29/100',
#       'sourceId': 178875761,
#       'name': '2',
#       'winning': False,
#       'change': -1}]},
#    {'sourceId': 170280187,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170280187,
#     'suspended': False,
#     'id': 1990690133,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 178888254,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 178888255,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170280187,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170280187,
#     'suspended': False,
#     'id': 1990690135,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '4/5',
#       'sourceId': 178888279,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '4/5',
#       'fractionalValue': '10/11',
#       'sourceId': 178888280,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170280187,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170280187,
#     'suspended': False,
#     'id': 1990690134,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '15/8',
#       'fractionalValue': '21/10',
#       'sourceId': 178888249,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '13/2',
#       'sourceId': 178888250,
#       'name': 'X',
#       'change': 1},
#      {'initialFractionalValue': '8/13',
#       'fractionalValue': '8/15',
#       'sourceId': 178888252,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170280187,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170280187,
#     'suspended': False,
#     'id': 1990690136,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/40',
#       'fractionalValue': '1/40',
#       'sourceId': 178888277,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '16/1',
#       'fractionalValue': '16/1',
#       'sourceId': 178888278,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170280187,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170280187,
#     'suspended': False,
#     'id': 1990690137,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '33/1',
#       'fractionalValue': '33/1',
#       'sourceId': 178888292,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/200',
#       'fractionalValue': '1/200',
#       'sourceId': 178888293,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265834},
#  'match_odds_13265836': {'markets': [{'sourceId': 170383877,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170383877,
#     'suspended': False,
#     'id': 1992450260,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '3/10',
#       'fractionalValue': '9/25',
#       'sourceId': 193045520,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '5/2',
#       'fractionalValue': '11/5',
#       'sourceId': 193045524,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170383877,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170383877,
#     'suspended': False,
#     'id': 1992496926,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 193070518,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 193070522,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170383877,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170383877,
#     'suspended': False,
#     'id': 1992496930,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '8/11',
#       'fractionalValue': '8/11',
#       'sourceId': 193070630,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/1',
#       'fractionalValue': '1/1',
#       'sourceId': 193070634,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170383877,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170383877,
#     'suspended': False,
#     'id': 1992496928,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '5/6',
#       'sourceId': 193070446,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '11/2',
#       'sourceId': 193070448,
#       'name': 'X',
#       'change': -1},
#      {'initialFractionalValue': '6/4',
#       'fractionalValue': '7/5',
#       'sourceId': 193070449,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170383877,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170383877,
#     'suspended': False,
#     'id': 1992496932,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/80',
#       'fractionalValue': '1/80',
#       'sourceId': 193070612,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '22/1',
#       'fractionalValue': '22/1',
#       'sourceId': 193070615,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170383877,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170383877,
#     'suspended': False,
#     'id': 1992496934,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '33/1',
#       'fractionalValue': '33/1',
#       'sourceId': 193070681,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/200',
#       'fractionalValue': '1/200',
#       'sourceId': 193070683,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265836},
#  'match_odds_13265837': {'markets': [{'sourceId': 170442027,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170442027,
#     'suspended': False,
#     'id': 1993978666,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '3/1',
#       'fractionalValue': '11/4',
#       'sourceId': 200117972,
#       'name': '1',
#       'change': -1},
#      {'initialFractionalValue': '1/4',
#       'fractionalValue': '29/100',
#       'sourceId': 200117973,
#       'name': '2',
#       'change': 1}]},
#    {'sourceId': 170442027,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170442027,
#     'suspended': False,
#     'id': 1994061479,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 200182670,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 200182672,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170442027,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170442027,
#     'suspended': False,
#     'id': 1994061481,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '5/6',
#       'fractionalValue': '4/5',
#       'sourceId': 200182745,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '5/6',
#       'fractionalValue': '10/11',
#       'sourceId': 200182746,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170442027,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170442027,
#     'suspended': False,
#     'id': 1994061480,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '15/8',
#       'fractionalValue': '7/5',
#       'sourceId': 200182655,
#       'name': '1',
#       'change': -1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '13/2',
#       'sourceId': 200182656,
#       'name': 'X',
#       'change': 1},
#      {'initialFractionalValue': '8/13',
#       'fractionalValue': '4/5',
#       'sourceId': 200182657,
#       'name': '2',
#       'change': 1}]},
#    {'sourceId': 170442027,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170442027,
#     'suspended': False,
#     'id': 1994061482,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/33',
#       'fractionalValue': '1/33',
#       'sourceId': 200182731,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '14/1',
#       'fractionalValue': '14/1',
#       'sourceId': 200182733,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265837},
#  'match_odds_13265838': {'markets': [{'sourceId': 170442029,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170442029,
#     'suspended': False,
#     'id': 1994042502,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '4/5',
#       'sourceId': 200117978,
#       'name': '1',
#       'winning': True,
#       'change': 0},
#      {'initialFractionalValue': '1/1',
#       'fractionalValue': '1/1',
#       'sourceId': 200117979,
#       'name': '2',
#       'winning': False,
#       'change': 0}]},
#    {'sourceId': 170442029,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170442029,
#     'suspended': False,
#     'id': 1994142822,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 200180496,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 200180499,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170442029,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170442029,
#     'suspended': False,
#     'id': 1994142824,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '8/11',
#       'sourceId': 200180822,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '1/1',
#       'sourceId': 200180826,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170442029,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170442029,
#     'suspended': False,
#     'id': 1994142823,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '11/10',
#       'fractionalValue': '13/10',
#       'sourceId': 200180430,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '11/2',
#       'fractionalValue': '6/1',
#       'sourceId': 200180440,
#       'name': 'X',
#       'change': 1},
#      {'initialFractionalValue': '21/20',
#       'fractionalValue': '5/6',
#       'sourceId': 200180448,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170442029,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170442029,
#     'suspended': False,
#     'id': 1994142825,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/40',
#       'fractionalValue': '1/50',
#       'sourceId': 200180797,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '16/1',
#       'fractionalValue': '18/1',
#       'sourceId': 200180799,
#       'name': 'No',
#       'change': 1}]},
#    {'sourceId': 170442029,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170442029,
#     'suspended': False,
#     'id': 1995529284,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '28/1',
#       'fractionalValue': '28/1',
#       'sourceId': 200180966,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/150',
#       'fractionalValue': '1/150',
#       'sourceId': 200180969,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265838},
#  'match_odds_13265840': {'markets': [{'sourceId': 170383879,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170383879,
#     'suspended': False,
#     'id': 1992450261,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '2/1',
#       'fractionalValue': '7/4',
#       'sourceId': 193045533,
#       'name': '1',
#       'winning': False,
#       'change': -1},
#      {'initialFractionalValue': '2/5',
#       'fractionalValue': '11/25',
#       'sourceId': 193045535,
#       'name': '2',
#       'winning': True,
#       'change': 1}]},
#    {'sourceId': 170383879,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170383879,
#     'suspended': False,
#     'id': 1992497007,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 193071913,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 193071915,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170383879,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170383879,
#     'suspended': False,
#     'id': 1992497009,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '4/5',
#       'sourceId': 193072228,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 193072236,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170383879,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170383879,
#     'suspended': False,
#     'id': 1992497008,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '6/4',
#       'fractionalValue': '7/4',
#       'sourceId': 193071901,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '6/1',
#       'sourceId': 193071903,
#       'name': 'X',
#       'change': 0},
#      {'initialFractionalValue': '4/5',
#       'fractionalValue': '4/6',
#       'sourceId': 193071904,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170383879,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170383879,
#     'suspended': False,
#     'id': 1992497010,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/80',
#       'fractionalValue': '1/80',
#       'sourceId': 193072182,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '22/1',
#       'fractionalValue': '22/1',
#       'sourceId': 193072193,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170383879,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170383879,
#     'suspended': False,
#     'id': 1992497011,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '22/1',
#       'fractionalValue': '22/1',
#       'sourceId': 193072335,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/80',
#       'fractionalValue': '1/80',
#       'sourceId': 193072339,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13265840},
#  'match_odds_13558575': {'markets': [{'sourceId': 170717971,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170717971,
#     'suspended': False,
#     'id': 1998288275,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '53/100',
#       'fractionalValue': '1/2',
#       'sourceId': 238403822,
#       'name': '1',
#       'winning': True,
#       'change': -1},
#      {'initialFractionalValue': '3/2',
#       'fractionalValue': '163/100',
#       'sourceId': 238403825,
#       'name': '2',
#       'winning': False,
#       'change': 1}]},
#    {'sourceId': 170717971,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170717971,
#     'suspended': False,
#     'id': 1998391412,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 238411144,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 238411145,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170717971,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170717971,
#     'suspended': False,
#     'id': 1998391414,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '4/5',
#       'sourceId': 238411252,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 238411254,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170717971,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170717971,
#     'suspended': False,
#     'id': 1998391413,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/5',
#       'fractionalValue': '1/1',
#       'sourceId': 238411131,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '6/1',
#       'fractionalValue': '11/2',
#       'sourceId': 238411132,
#       'name': 'X',
#       'change': -1},
#      {'initialFractionalValue': '6/4',
#       'fractionalValue': '6/5',
#       'sourceId': 238411134,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170717971,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170717971,
#     'suspended': False,
#     'id': 1998391415,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/33',
#       'fractionalValue': '1/33',
#       'sourceId': 238411236,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '14/1',
#       'fractionalValue': '14/1',
#       'sourceId': 238411237,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170717971,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170717971,
#     'suspended': False,
#     'id': 1998391416,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '25/1',
#       'fractionalValue': '25/1',
#       'sourceId': 238411316,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/100',
#       'fractionalValue': '1/100',
#       'sourceId': 238411318,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13558575},
#  'match_odds_13558576': {'markets': [{'sourceId': 170718335,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170718335,
#     'suspended': False,
#     'id': 1998377005,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '73/100',
#       'fractionalValue': '73/100',
#       'sourceId': 238464918,
#       'name': '1',
#       'winning': False,
#       'change': 0},
#      {'initialFractionalValue': '11/10',
#       'fractionalValue': '11/10',
#       'sourceId': 238464919,
#       'name': '2',
#       'winning': True,
#       'change': 0}]},
#    {'sourceId': 170718335,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170718335,
#     'suspended': False,
#     'id': 1998494428,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 238471165,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 238471166,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170718335,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170718335,
#     'suspended': False,
#     'id': 1998494430,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '4/6',
#       'fractionalValue': '4/6',
#       'sourceId': 238471279,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '11/10',
#       'fractionalValue': '11/10',
#       'sourceId': 238471281,
#       'name': 'No',
#       'change': 0}]},
#    {'sourceId': 170718335,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170718335,
#     'suspended': False,
#     'id': 1998494429,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/1',
#       'fractionalValue': '21/20',
#       'sourceId': 238471145,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '7/1',
#       'fractionalValue': '7/1',
#       'sourceId': 238471148,
#       'name': 'X',
#       'change': 0},
#      {'initialFractionalValue': '21/20',
#       'fractionalValue': '1/1',
#       'sourceId': 238471151,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170718335,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170718335,
#     'suspended': False,
#     'id': 1998494431,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/66',
#       'fractionalValue': '1/100',
#       'sourceId': 238471260,
#       'name': 'Yes',
#       'change': -1},
#      {'initialFractionalValue': '20/1',
#       'fractionalValue': '25/1',
#       'sourceId': 238471262,
#       'name': 'No',
#       'change': 1}]}],
#   'eventId': 13558576},
#  'match_odds_13569002': {'markets': [{'sourceId': 170877033,
#     'structureType': 1,
#     'marketId': 1,
#     'marketName': 'Full time',
#     'isLive': False,
#     'fid': 170877033,
#     'suspended': False,
#     'id': 2000710223,
#     'marketGroup': '1X2',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '2/5',
#       'fractionalValue': '11/25',
#       'sourceId': 257894873,
#       'name': '1',
#       'winning': True,
#       'change': 1},
#      {'initialFractionalValue': '2/1',
#       'fractionalValue': '7/4',
#       'sourceId': 257894874,
#       'name': '2',
#       'winning': False,
#       'change': -1}]},
#    {'sourceId': 170877033,
#     'structureType': 1,
#     'marketId': 26,
#     'marketName': 'To win the toss',
#     'isLive': False,
#     'fid': 170877033,
#     'suspended': False,
#     'id': 2000836065,
#     'marketGroup': 'To win the toss',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 257912541,
#       'name': '1',
#       'change': 0},
#      {'initialFractionalValue': '10/11',
#       'fractionalValue': '10/11',
#       'sourceId': 257912542,
#       'name': '2',
#       'change': 0}]},
#    {'sourceId': 170877033,
#     'structureType': 1,
#     'marketId': 30,
#     'marketName': 'A hundred to be scored in match',
#     'isLive': False,
#     'fid': 170877033,
#     'suspended': False,
#     'id': 2000836067,
#     'marketGroup': 'A hundred to be scored in match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '11/10',
#       'fractionalValue': '5/4',
#       'sourceId': 257912577,
#       'name': 'Yes',
#       'change': 1},
#      {'initialFractionalValue': '4/6',
#       'fractionalValue': '4/7',
#       'sourceId': 257912578,
#       'name': 'No',
#       'change': -1}]},
#    {'sourceId': 170877033,
#     'structureType': 1,
#     'marketId': 31,
#     'marketName': 'Most match sixes',
#     'isLive': False,
#     'fid': 170877033,
#     'suspended': False,
#     'id': 2000836066,
#     'marketGroup': 'Most match sixes',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '8/15',
#       'fractionalValue': '4/5',
#       'sourceId': 257912526,
#       'name': '1',
#       'change': 1},
#      {'initialFractionalValue': '13/2',
#       'fractionalValue': '6/1',
#       'sourceId': 257912527,
#       'name': 'X',
#       'change': -1},
#      {'initialFractionalValue': '2/1',
#       'fractionalValue': '6/4',
#       'sourceId': 257912528,
#       'name': '2',
#       'change': -1}]},
#    {'sourceId': 170877033,
#     'structureType': 1,
#     'marketId': 32,
#     'marketName': 'A fifty to be scored in the match',
#     'isLive': False,
#     'fid': 170877033,
#     'suspended': False,
#     'id': 2000836068,
#     'marketGroup': 'A fifty to be scored in the match',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '1/25',
#       'fractionalValue': '1/20',
#       'sourceId': 257912573,
#       'name': 'Yes',
#       'change': 1},
#      {'initialFractionalValue': '12/1',
#       'fractionalValue': '10/1',
#       'sourceId': 257912574,
#       'name': 'No',
#       'change': -1}]},
#    {'sourceId': 170877033,
#     'structureType': 1,
#     'marketId': 34,
#     'marketName': 'To go to super over?',
#     'isLive': False,
#     'fid': 170877033,
#     'suspended': False,
#     'id': 2000836069,
#     'marketGroup': 'To go to super over?',
#     'marketPeriod': 'Full time',
#     'choices': [{'initialFractionalValue': '33/1',
#       'fractionalValue': '33/1',
#       'sourceId': 257912598,
#       'name': 'Yes',
#       'change': 0},
#      {'initialFractionalValue': '1/200',
#       'fractionalValue': '1/200',
#       'sourceId': 257912599,
#       'name': 'No',
#       'change': 0}]}],
#   'eventId': 13569002}}

# %% [markdown]
# # Depth json to flatten_json

# %%
# Function for Convert a nested json dictionary to flatten json or dictionary
def flatten_json(nested_json, parent_key='', sep='_'):

    items = []
    
    # If the value is a dictionary
    if isinstance(nested_json, dict):
        for key, value in nested_json.items():
            new_key = f"{parent_key}{sep}{key}" if parent_key else key
            items.extend(flatten_json(value, new_key, sep=sep).items())
    
    # If the value is a list
    elif isinstance(nested_json, list): 
        for index, item in enumerate(nested_json):
            new_key = f"{parent_key}{sep}{index}" if parent_key else str(index)
            items.extend(flatten_json(item, new_key, sep=sep).items())
            
    # If the value is neither dict nor list
    else:
        items.append((parent_key, nested_json))

    return dict(items)

# %% [markdown]
# # Flatten Json to Row column

# %%
def process_json_file(data):
    try:
        # Normalize JSON data
        if isinstance(data, list):  # JSON is an array of objects
            flat_data = [flatten_json(item) for item in data]
        elif isinstance(data, dict):  # JSON is a single dictionary
            flat_data = [flatten_json(data)]
        else:
            raise ValueError("Unsupported JSON format")

        # Convert to DataFrame
        df = pd.DataFrame(flat_data)
        return df


    except json.JSONDecodeError:
        print("Error: Invalid JSON file.")
    except Exception as e:
        print(f"Error: {str(e)}")

# %%
match_odds_detail.keys()
# Out:
# dict_keys(['match_odds_13265827', 'match_odds_13265828', 'match_odds_13265829', 'match_odds_13265830', 'match_odds_13265831', 'match_odds_13265832', 'match_odds_13265833', 'match_odds_13265834', 'match_odds_13265836', 'match_odds_13265837', 'match_odds_13265838', 'match_odds_13265840', 'match_odds_13558575', 'match_odds_13558576', 'match_odds_13569002'])

# %%
match_odds_detail['match_odds_13265837']
# Out:
# {'markets': [{'sourceId': 170442027,
#    'structureType': 1,
#    'marketId': 1,
#    'marketName': 'Full time',
#    'isLive': False,
#    'fid': 170442027,
#    'suspended': False,
#    'id': 1993978666,
#    'marketGroup': '1X2',
#    'marketPeriod': 'Full time',
#    'choices': [{'initialFractionalValue': '3/1',
#      'fractionalValue': '11/4',
#      'sourceId': 200117972,
#      'name': '1',
#      'change': -1},
#     {'initialFractionalValue': '1/4',
#      'fractionalValue': '29/100',
#      'sourceId': 200117973,
#      'name': '2',
#      'change': 1}]},
#   {'sourceId': 170442027,
#    'structureType': 1,
#    'marketId': 26,
#    'marketName': 'To win the toss',
#    'isLive': False,
#    'fid': 170442027,
#    'suspended': False,
#    'id': 1994061479,
#    'marketGroup': 'To win the toss',
#    'marketPeriod': 'Full time',
#    'choices': [{'initialFractionalValue': '10/11',
#      'fractionalValue': '10/11',
#      'sourceId': 200182670,
#      'name': '1',
#      'change': 0},
#     {'initialFractionalValue': '10/11',
#      'fractionalValue': '10/11',
#      'sourceId': 200182672,
#      'name': '2',
#      'change': 0}]},
#   {'sourceId': 170442027,
#    'structureType': 1,
#    'marketId': 30,
#    'marketName': 'A hundred to be scored in match',
#    'isLive': False,
#    'fid': 170442027,
#    'suspended': False,
#    'id': 1994061481,
#    'marketGroup': 'A hundred to be scored in match',
#    'marketPeriod': 'Full time',
#    'choices': [{'initialFractionalValue': '5/6',
#      'fractionalValue': '4/5',
#      'sourceId': 200182745,
#      'name': 'Yes',
#      'change': -1},
#     {'initialFractionalValue': '5/6',
#      'fractionalValue': '10/11',
#      'sourceId': 200182746,
#      'name': 'No',
#      'change': 1}]},
#   {'sourceId': 170442027,
#    'structureType': 1,
#    'marketId': 31,
#    'marketName': 'Most match sixes',
#    'isLive': False,
#    'fid': 170442027,
#    'suspended': False,
#    'id': 1994061480,
#    'marketGroup': 'Most match sixes',
#    'marketPeriod': 'Full time',
#    'choices': [{'initialFractionalValue': '15/8',
#      'fractionalValue': '7/5',
#      'sourceId': 200182655,
#      'name': '1',
#      'change': -1},
#     {'initialFractionalValue': '6/1',
#      'fractionalValue': '13/2',
#      'sourceId': 200182656,
#      'name': 'X',
#      'change': 1},
#     {'initialFractionalValue': '8/13',
#      'fractionalValue': '4/5',
#      'sourceId': 200182657,
#      'name': '2',
#      'change': 1}]},
#   {'sourceId': 170442027,
#    'structureType': 1,
#    'marketId': 32,
#    'marketName': 'A fifty to be scored in the match',
#    'isLive': False,
#    'fid': 170442027,
#    'suspended': False,
#    'id': 1994061482,
#    'marketGroup': 'A fifty to be scored in the match',
#    'marketPeriod': 'Full time',
#    'choices': [{'initialFractionalValue': '1/33',
#      'fractionalValue': '1/33',
#      'sourceId': 200182731,
#      'name': 'Yes',
#      'change': 0},
#     {'initialFractionalValue': '14/1',
#      'fractionalValue': '14/1',
#      'sourceId': 200182733,
#      'name': 'No',
#      'change': 0}]}],
#  'eventId': 13265837}

# %% [markdown]
# # Pass this on parent json

# %%
def process_dictionary(data):
    all_dataframe = {}
    
    for key in data:
        if data[key] is not None and data[key] != "" and data[key] != {}:
            if isinstance(data[key], list):  # Check if value is a list
                dataframe = pd.DataFrame(columns=process_json_file(flatten_json(data[key][0])).columns)
                for i in range(len(data[key])):
                    flatten_dict = flatten_json(data[key][i])
                    new_dataframe = process_json_file(flatten_dict)
                    dataframe = pd.concat([dataframe, new_dataframe])
                    
                    # Deleting field translation columns
                    dataframe = dataframe.loc[:, ~dataframe.columns.str.contains("fieldtranslations|translation", case=False, regex=True)]
                
                all_dataframe[key] = dataframe
            else:
                flatten_dict = flatten_json(data[key])
                dataframe = process_json_file(flatten_dict)
                
                # Deleting field translation columns
                dataframe = dataframe.loc[:, ~dataframe.columns.str.contains("fieldtranslations|translation", case=False, regex=True)]
                
                all_dataframe[key] = dataframe
    
    return all_dataframe

# %%
all_match_odds_data = pd.DataFrame(columns=['sourceId', 'structureType', 'marketId', 'marketName', 'isLive', 'fid',
       'suspended', 'id', 'marketGroup', 'marketPeriod',
       'choices_0_initialFractionalValue', 'choices_0_fractionalValue',
       'choices_0_sourceId', 'choices_0_name', 'choices_0_winning',
       'choices_0_change', 'choices_1_initialFractionalValue',
       'choices_1_fractionalValue', 'choices_1_sourceId', 'choices_1_name',
       'choices_1_winning', 'choices_1_change',
       'choices_2_initialFractionalValue', 'choices_2_fractionalValue',
       'choices_2_sourceId', 'choices_2_name', 'choices_2_change'])
all_match_odds_data
# Out:
# Empty DataFrame
# Columns: [sourceId, structureType, marketId, marketName, isLive, fid, suspended, id, marketGroup, marketPeriod, choices_0_initialFractionalValue, choices_0_fractionalValue, choices_0_sourceId, choices_0_name, choices_0_winning, choices_0_change, choices_1_initialFractionalValue, choices_1_fractionalValue, choices_1_sourceId, choices_1_name, choices_1_winning, choices_1_change, choices_2_initialFractionalValue, choices_2_fractionalValue, choices_2_sourceId, choices_2_name, choices_2_change]
# Index: []
#
# [0 rows x 27 columns]

# %%
for i in match_odds_detail.keys():
    match_id = int(i.split('_')[-1])
    match_odds = process_dictionary(match_odds_detail[i])['markets']
    match_odds['match_id'] = match_id
    all_match_odds_data = pd.concat([all_match_odds_data, match_odds], ignore_index=True)
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_16868\1469463462.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_odds_data = pd.concat([all_match_odds_data, match_odds], ignore_index=True)

# %%
# saving file from Api
all_match_odds_data.to_excel('all_match_odds_data.xlsx', index=False)
