# %% [markdown]
# # Cricket Matches Graph json file to row data

# %%
import numpy as np
import pandas as pd
import json
import http.client
import time  

# List of match IDs
match_ids = [
    13265827, 13265828, 13265829, 13265830, 13265831, 13265832, 13265833, 
    13265834, 13265836, 13265837, 13265838, 13265840, 13558575, 13558576, 13569002
]

# API connection setup
conn = http.client.HTTPSConnection("allsportsapi2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "693b14936cmshb4229d5afd9d447p186b67jsn499928bbef0a",
    'x-rapidapi-host': "allsportsapi2.p.rapidapi.com"
}

# Parent dictionary to store all match data
parent_json = {}

# Loop through each match ID
for match_id in match_ids:
    try:
        # Make API request
        conn.request("GET", f"/api/cricket/match/{match_id}/graph", headers=headers)
        res = conn.getresponse()
        data = res.read()
        
        # Convert response to JSON
        data_json = json.loads(data.decode("utf-8"))
        
        # Store JSON in the parent dictionary with match_id as key
        parent_json[f"match_graph_details_{match_id}"] = data_json

        print(f"Data collected for Match ID {match_id}")

    except Exception as e:
        print(f"Error fetching data for Match ID {match_id}: {e}")

    time.sleep(1)  # Optional: Delay to prevent rate limits

# Save all match data in a single JSON file
with open("all_match_graph_data.json", "w", encoding="utf-8") as f:
    json.dump(parent_json, f, indent=4)

print("All match data saved in all_match_data.json")
# Out:
# Data collected for Match ID 13265827
# Data collected for Match ID 13265828
# Data collected for Match ID 13265829
# Data collected for Match ID 13265830
# Data collected for Match ID 13265831
# Data collected for Match ID 13265832
# Error fetching data for Match ID 13265833: Expecting value: line 1 column 1 (char 0)
# Data collected for Match ID 13265834
# Error fetching data for Match ID 13265836: Expecting value: line 1 column 1 (char 0)
# Data collected for Match ID 13265837
# Data collected for Match ID 13265838
# Data collected for Match ID 13265840
# Data collected for Match ID 13558575
# Data collected for Match ID 13558576
# Data collected for Match ID 13569002
# All match data saved in all_match_data.json

# %% [markdown]
# ## Loading Json file

# %%
import numpy as np
import pandas as pd
import json
with open("all_match_graph_data.json", "r", encoding="utf-8") as f:
   match_graph = json.load(f)
match_graph
# Out:
# {'match_graph_details_13265827': {'graphPoints': {'homeInnings': [{'inning': 2,
#      'runs': [{'over': 1, 'runs': 1},
#       {'over': 2, 'runs': 3},
#       {'over': 3, 'runs': 5},
#       {'over': 4, 'runs': 8, 'wickets': 1},
#       {'over': 5, 'runs': 12},
#       {'over': 6, 'runs': 14},
#       {'over': 7, 'runs': 14},
#       {'over': 8, 'runs': 19},
#       {'over': 9, 'runs': 21},
#       {'over': 10, 'runs': 22, 'wickets': 1},
#       {'over': 11, 'runs': 24},
#       {'over': 12, 'runs': 33},
#       {'over': 13, 'runs': 35},
#       {'over': 14, 'runs': 41},
#       {'over': 15, 'runs': 49},
#       {'over': 16, 'runs': 55},
#       {'over': 17, 'runs': 55},
#       {'over': 18, 'runs': 60},
#       {'over': 19, 'runs': 65},
#       {'over': 20, 'runs': 66},
#       {'over': 21, 'runs': 69, 'wickets': 1},
#       {'over': 22, 'runs': 70},
#       {'over': 23, 'runs': 72},
#       {'over': 24, 'runs': 80},
#       {'over': 25, 'runs': 83},
# ...

# %% [markdown]
# # Depth json To flatted Json

# %%
# Function for Convert a nested json dictionary to flatten json or dictionary
def flatten_json(nested_json, parent_key='', sep='_'):

    items = []
    
    # If the value is a dictionary
    if isinstance(nested_json, dict):
        for key, value in nested_json.items():
            new_key = f"{parent_key}{sep}{key}" if parent_key else key
            items.extend(flatten_json(value, new_key, sep=sep).items())
    
    # If the value is a list
    elif isinstance(nested_json, list): 
        for index, item in enumerate(nested_json):
            new_key = f"{parent_key}{sep}{index}" if parent_key else str(index)
            items.extend(flatten_json(item, new_key, sep=sep).items())
            
    # If the value is neither dict nor list
    else:
        items.append((parent_key, nested_json))

    return dict(items)

# %% [markdown]
# # Flatten Json to Column Row

# %%
def process_json_file(data):
    try:
        # Normalize JSON data
        if isinstance(data, list):  # JSON is an array of objects
            flat_data = [flatten_json(item) for item in data]
        elif isinstance(data, dict):  # JSON is a single dictionary
            flat_data = [flatten_json(data)]
        else:
            raise ValueError("Unsupported JSON format")

        # Convert to DataFrame
        df = pd.DataFrame(flat_data)
        return df


    except json.JSONDecodeError:
        print("Error: Invalid JSON file.")
    except Exception as e:
        print(f"Error: {str(e)}")

# %% [markdown]
# ## 1. first level keys

# %%
# first level keys
print("Data Type: ", type(data))
match_graph.keys()
# Out:
# Data Type:  <class 'dict'>
# dict_keys(['match_graph_details_13265827', 'match_graph_details_13265828', 'match_graph_details_13265829', 'match_graph_details_13265830', 'match_graph_details_13265831', 'match_graph_details_13265832', 'match_graph_details_13265834', 'match_graph_details_13265837', 'match_graph_details_13265838', 'match_graph_details_13265840', 'match_graph_details_13558575', 'match_graph_details_13558576', 'match_graph_details_13569002'])

# %%
for i in match_graph.keys():
    print(i)
# Out:
# match_graph_details_13265827
# match_graph_details_13265828
# match_graph_details_13265829
# match_graph_details_13265830
# match_graph_details_13265831
# match_graph_details_13265832
# match_graph_details_13265834
# match_graph_details_13265837
# match_graph_details_13265838
# match_graph_details_13265840
# match_graph_details_13558575
# match_graph_details_13558576
# match_graph_details_13569002

# %% [markdown]
# # Process Dictionary file to data

# %%
def process_dictionary(data):
    all_dataframe = {}
    parent_json = {}

    for key in data:
        if data[key] is not None and data[key] != "" and data[key] != {}:
            if isinstance(data[key], list):  # If value is a list
                dataframe = pd.DataFrame(columns=process_json_file(flatten_json(data[key][0])).columns)
                for i in range(len(data[key])):
                    flatten_dict = flatten_json(data[key][i])
                    new_dataframe = process_json_file(flatten_dict)
                    dataframe = pd.concat([dataframe, new_dataframe], ignore_index=True)

                    # Deleting field translation columns
                    dataframe = dataframe.loc[:, ~dataframe.columns.str.contains("fieldtranslations|translation", case=False, regex=True)]

                if dataframe.shape[1] >= 10:  # If columns are 10 or more
                    all_dataframe[key] = dataframe
                else:
                    parent_json[key] = data[key]

            elif isinstance(data[key], dict):  # If value is a dictionary
                flatten_dict = flatten_json(data[key])
                dataframe = process_json_file(flatten_dict)

                # Deleting field translation columns
                dataframe = dataframe.loc[:, ~dataframe.columns.str.contains("fieldtranslations|translation", case=False, regex=True)]

                if dataframe.shape[1] >= 5:  # If columns are 5 or more
                    all_dataframe[key] = dataframe
                else:
                    parent_json[key] = data[key]
            else:
                parent_json[key] = data[key]

    # Convert parent_json into a DataFrame and store it in all_dataframe
    all_dataframe["parent_df"] = process_json_file(flatten_json(parent_json))

    return all_dataframe

# %%
data.keys()
# Out:
# dict_keys(['homeInnings', 'awayInnings'])

# %%
data = match_graph['match_graph_details_13265830']
data
# Out:
# {'graphPoints': {'homeInnings': [{'inning': 2,
#     'runs': [{'over': 1, 'runs': 8},
#      {'over': 2, 'runs': 17},
#      {'over': 3, 'runs': 21},
#      {'over': 4, 'runs': 27, 'wickets': 1},
#      {'over': 5, 'runs': 31, 'wickets': 1},
#      {'over': 6, 'runs': 43},
#      {'over': 7, 'runs': 50},
#      {'over': 8, 'runs': 57},
#      {'over': 9, 'runs': 62},
#      {'over': 10, 'runs': 76},
#      {'over': 11, 'runs': 79},
#      {'over': 12, 'runs': 85},
#      {'over': 13, 'runs': 92},
#      {'over': 14, 'runs': 94},
#      {'over': 15, 'runs': 103},
#      {'over': 16, 'runs': 109},
#      {'over': 17, 'runs': 114},
#      {'over': 18, 'runs': 118},
#      {'over': 19, 'runs': 122},
#      {'over': 20, 'runs': 129, 'wickets': 1},
#      {'over': 21, 'runs': 135},
#      {'over': 22, 'runs': 136},
#      {'over': 23, 'runs': 140, 'wickets': 1},
#      {'over': 24, 'runs': 146},
#      {'over': 25, 'runs': 156},
#      {'over': 26, 'runs': 161},
# ...

# %%
int('match_graph_details_13265830'.split('_')[-1])
# Out:
# 13265830

# %%
all_match_graph_data = pd.DataFrame(columns=['over', 'runs', 'wickets', 'match_id'])
all_match_graph_data
# Out:
# Empty DataFrame
# Columns: [over, runs, wickets, match_id]
# Index: []

# %% [markdown]
# # This is the main code to collect and concat all data together

# %%
all_match_graph_data = pd.DataFrame(columns=['over', 'runs', 'wickets', 'match_id'])
all_match_graph_data
for i in match_graph.keys():
    # extracting match_id from match_name
    match_id = int(i.split('_')[-1])

    # for a particular match id assigning data 
    data = match_graph[i]  

    # homeinnings data extracting
    homeinnings = process_json_file(data['graphPoints']['homeInnings'][0]['runs'])
    homeinnings['inning'] = 'home'
    homeinnings['match_id'] = match_id
    
    # awayinnings data extractiong
    awayinnings = process_json_file(data['graphPoints']['awayInnings'][0]['runs'])
    awayinnings['inning'] = 'away'
    awayinnings['match_id'] = match_id 

    # concatenating home and away inings data
    match_graph_data = pd.concat([homeinnings, awayinnings],ignore_index=True)
    all_match_graph_data = pd.concat([all_match_graph_data, match_graph_data], ignore_index=False)
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_8000\2411563021.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_graph_data = pd.concat([all_match_graph_data, match_graph_data], ignore_index=False)

# %%
all_match_graph_data
# Out:
#    over runs  wickets  match_id inning
# 0     1    1      NaN  13265827   home
# 1     2    3      NaN  13265827   home
# 2     3    5      NaN  13265827   home
# 3     4    8      1.0  13265827   home
# 4     5   12      NaN  13265827   home
# ..  ...  ...      ...       ...    ...
# 94   46  212      1.0  13569002   away
# 95   47  216      NaN  13569002   away
# 96   48  227      NaN  13569002   away
# 97   49  239      1.0  13569002   away
# 98   50  251      NaN  13569002   away
#
# [1203 rows x 5 columns]

# %%
# Saving all Data
all_match_graph_data.to_excel("all_match_graph_data.xlsx", index=False)

# %% [markdown]
# ## homeInning data Extraction

# %%
match_id = int('match_graph_details_13265830'.split('_')[-1])
homeinnings = process_json_file(data['graphPoints']['homeInnings'][0]['runs'])
homeinnings['inning'] = 'home'
homeinnings['match_id'] = match_id

awayinnings = process_json_file(data['graphPoints']['awayInnings'][0]['runs'])
awayinnings['inning'] = 'away'
awayinnings['match_id'] = match_id 

pd.concat([homeinnings, awayinnings], ignore_index=True)
# Out:
#     over  runs  wickets inning  match_id
# 0      1     8      NaN   home  13265830
# 1      2    17      NaN   home  13265830
# 2      3    21      NaN   home  13265830
# 3      4    27      1.0   home  13265830
# 4      5    31      1.0   home  13265830
# ..   ...   ...      ...    ...       ...
# 93    46   311      NaN   away  13265830
# 94    47   321      1.0   away  13265830
# 95    48   325      1.0   away  13265830
# 96    49   336      NaN   away  13265830
# 97    50   351      1.0   away  13265830
#
# [98 rows x 5 columns]

# %%
pd.concat([main_dataframe,pd.concat([homeinnings, awayinnings], ignore_index=True)], ignore_index=True)
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_8000\2557685421.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat([main_dataframe,pd.concat([homeinnings, awayinnings], ignore_index=True)], ignore_index=True)
#    over runs  wickets  match_id inning
# 0     1    8      NaN  13265830   home
# 1     2   17      NaN  13265830   home
# 2     3   21      NaN  13265830   home
# 3     4   27      1.0  13265830   home
# 4     5   31      1.0  13265830   home
# ..  ...  ...      ...       ...    ...
# 93   46  311      NaN  13265830   away
# 94   47  321      1.0  13265830   away
# 95   48  325      1.0  13265830   away
# 96   49  336      NaN  13265830   away
# 97   50  351      1.0  13265830   away
#
# [98 rows x 5 columns]

# %%
match_id = 13569002
awayinnings = process_json_file(data['graphPoints']['awayInnings'][0]['runs'])
awayinnings['inning'] = 'away'
awayinnings['match_id'] = match_id 
awayinnings
# Out:
#     over  runs  wickets inning  match_id
# 0      1     4      NaN   away  13569002
# 1      2     6      NaN   away  13569002
# 2      3    10      NaN   away  13569002
# 3      4    26      NaN   away  13569002
# 4      5    37      NaN   away  13569002
# 5      6    46      NaN   away  13569002
# 6      7    51      NaN   away  13569002
# 7      8    58      1.0   away  13569002
# 8      9    64      NaN   away  13569002
# 9     10    69      NaN   away  13569002
# 10    11    73      1.0   away  13569002
# 11    12    75      NaN   away  13569002
# 12    13    77      1.0   away  13569002
# 13    14    81      NaN   away  13569002
# 14    15    83      NaN   away  13569002
# 15    16    85      NaN   away  13569002
# 16    17    90      NaN   away  13569002
# 17    18    95      NaN   away  13569002
# 18    19    99      NaN   away  13569002
# 19    20   101      NaN   away  13569002
# 20    21   102      NaN   away  13569002
# 21    22   104      NaN   away  13569002
# ...

# %%
# saving file
# homeinnings.to_excel('home_inning.xlsx', index=False)

# %%
# awayinnings.to_excel('away_inning.xlsx', index= False)

# %%
pd.concat([homeinnings, awayinnings], ignore_index=True)
# Out:
#     over  runs  wickets inning  match_id
# 0      1     9      NaN   home  13569002
# 1      2    22      NaN   home  13569002
# 2      3    25      NaN   home  13569002
# 3      4    30      NaN   home  13569002
# 4      5    31      NaN   home  13569002
# ..   ...   ...      ...    ...       ...
# 94    46   212      1.0   away  13569002
# 95    47   216      NaN   away  13569002
# 96    48   227      NaN   away  13569002
# 97    49   239      1.0   away  13569002
# 98    50   251      NaN   away  13569002
#
# [99 rows x 5 columns]
