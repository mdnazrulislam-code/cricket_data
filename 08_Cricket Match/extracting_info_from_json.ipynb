# %% [markdown]
# # Cricket Match

# %%
import numpy as np
import pandas as pd
import json
import http.client

match_id = 13569002  # Your match ID (you can change this dynamically)

# API connection setup
conn = http.client.HTTPSConnection("allsportsapi2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "693b14936cmshb4229d5afd9d447p186b67jsn499928bbef0a",
    'x-rapidapi-host': "allsportsapi2.p.rapidapi.com"
}

# Use f-string to dynamically insert match_id
conn.request("GET", f"/api/cricket/match/{match_id}", headers=headers)

res = conn.getresponse()
data = res.read()

# Convert JSON response
data_json = json.loads(data.decode("utf-8"))

# Save JSON data to a file
file_name = f"api_data_{match_id}.json"
with open(file_name, "w", encoding="utf-8") as f:
    json.dump(data_json, f, indent=4)

print(f"Data saved as {file_name}")
# Out:
# Data saved as api_data_13569002.json

# %% [markdown]
# # This below code give all data for each match

# %%
import numpy as np
import pandas as pd
import json
import http.client
import time  
no_result_match_ids = [13265833,13265836,13265837]

# List of match IDs
match_ids = [13265827,13265828,13265829,13265830,13265831,13265832,13265833,13265834,13265836, 13265837,13265838,13265840, 13558575,13558576,13569002]  

# API connection setup
conn = http.client.HTTPSConnection("allsportsapi2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "693b14936cmshb4229d5afd9d447p186b67jsn499928bbef0a",
    'x-rapidapi-host': "allsportsapi2.p.rapidapi.com"
}

# Dictionary to store match data
match_data_dict = {}

# Loop through each match ID
for match_id in match_ids:
    try:
        # Make API request
        conn.request("GET", f"/api/cricket/match/{match_id}", headers=headers)
        res = conn.getresponse()
        data = res.read()
        
        # Convert response to JSON
        data_json = json.loads(data.decode("utf-8"))
        match_data_dict[match_id] = data_json  # Store JSON in dictionary
        
        # Save JSON file for each match
        file_name = f"match_details_{match_id}.json"
        with open(file_name, "w", encoding="utf-8") as f:
            json.dump(data_json, f, indent=4)

        print(f"Data for Match ID {match_id} saved as {file_name}")

    except Exception as e:
        print(f"Error fetching data for Match ID {match_id}: {e}")

    time.sleep(1)  # Optional: Delay to prevent rate limits

# Now you have all JSON data stored in 'match_data_dict'
print("All match data collected successfully.")
# Out:
# Data for Match ID 13265827 saved as match_details_13265827.json
# Data for Match ID 13265828 saved as match_details_13265828.json
# Data for Match ID 13265829 saved as match_details_13265829.json
# Data for Match ID 13265830 saved as match_details_13265830.json
# Data for Match ID 13265831 saved as match_details_13265831.json
# Data for Match ID 13265832 saved as match_details_13265832.json
# Data for Match ID 13265833 saved as match_details_13265833.json
# Data for Match ID 13265834 saved as match_details_13265834.json
# Data for Match ID 13265836 saved as match_details_13265836.json
# Data for Match ID 13265837 saved as match_details_13265837.json
# Data for Match ID 13265838 saved as match_details_13265838.json
# Data for Match ID 13265840 saved as match_details_13265840.json
# Data for Match ID 13558575 saved as match_details_13558575.json
# Data for Match ID 13558576 saved as match_details_13558576.json
# Data for Match ID 13569002 saved as match_details_13569002.json
# All match data collected successfully.

# %% [markdown]
# # This below code give all match data into one file

# %%
import numpy as np
import pandas as pd
import json
import http.client
import time  

# List of match IDs
match_ids = [
    13265827, 13265828, 13265829, 13265830, 13265831, 13265832, 13265833, 
    13265834, 13265836, 13265837, 13265838, 13265840, 13558575, 13558576, 13569002
]

# API connection setup
conn = http.client.HTTPSConnection("allsportsapi2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "693b14936cmshb4229d5afd9d447p186b67jsn499928bbef0a",
    'x-rapidapi-host': "allsportsapi2.p.rapidapi.com"
}

# Parent dictionary to store all match data
parent_json = {}

# Loop through each match ID
for match_id in match_ids:
    try:
        # Make API request
        conn.request("GET", f"/api/cricket/match/{match_id}", headers=headers)
        res = conn.getresponse()
        data = res.read()
        
        # Convert response to JSON
        data_json = json.loads(data.decode("utf-8"))
        
        # Store JSON in the parent dictionary with match_id as key
        parent_json[f"match_details_{match_id}"] = data_json

        print(f"Data collected for Match ID {match_id}")

    except Exception as e:
        print(f"Error fetching data for Match ID {match_id}: {e}")

    time.sleep(1)  # Optional: Delay to prevent rate limits

# Save all match data in a single JSON file
with open("all_match_data.json", "w", encoding="utf-8") as f:
    json.dump(parent_json, f, indent=4)

print("All match data saved in all_match_data.json")
# Out:
# Data collected for Match ID 13265827
# Data collected for Match ID 13265828
# Data collected for Match ID 13265829
# Data collected for Match ID 13265830
# Data collected for Match ID 13265831
# Data collected for Match ID 13265832
# Data collected for Match ID 13265833
# Data collected for Match ID 13265834
# Data collected for Match ID 13265836
# Data collected for Match ID 13265837
# Data collected for Match ID 13265838
# Data collected for Match ID 13265840
# Data collected for Match ID 13558575
# Data collected for Match ID 13558576
# Data collected for Match ID 13569002
# All match data saved in all_match_data.json

# %% [markdown]
# ## Loading Json file

# %%
with open("all_match_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)
data
# Out:
# {'match_details_13265827': {'event': {'tournament': {'name': 'ICC Champions Trophy, Group A',
#     'slug': 'icc-champions-trophy-group-a',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7160,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': True,
#     'groupName': 'Group A',
#     'competitionType': 1,
#     'isLive': False,
#     'id': 40585,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة A',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप ए',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ এ'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'efAbsffAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'venue': {'city': {'name': 'Karachi'},
#     'hidden': True,
#     'slug': 'national-stadium',
#     'name': 'National Stadium',
#     'capacity': 34228,
#     'id': 25028,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب الوطني',
#       'hi': 'नेशनल स्टेडियम',
#       'bn': 'ন্যাশনাল স্টেডিয়াম'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'National Stadium', 'capacity': 34228}},
#    'homeTeam': {'name': 'Pakistan',
#     'slug': 'pakistan',
#     'shortName': 'PAK',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 20334,
#     'venue': {'city': {'name': 'Lahore'},
#      'hidden': True,
#      'slug': 'gaddafi-stadium',
#      'name': 'Gaddafi Stadium',
#      'capacity': 27000,
#      'id': 15542,
#      'country': {'alpha2': 'PK',
#       'alpha3': 'PAK',
#       'name': 'Pakistan',
#       'slug': 'pakistan'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب القذافي',
#        'hi': 'गद्दाफी स्टेडियम',
#        'bn': 'গাদ্দাফি স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Gaddafi Stadium', 'capacity': 27000}},
#     'nameCode': 'PAK',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187754,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Pakistan',
#     'teamColors': {'primary': '#007f4b',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'باكستان',
#       'hi': 'पाकिस्तान',
#       'bn': 'পাকিস্তান'},
#      'shortNameTranslation': {'ar': 'باكستان', 'hi': 'पीएके', 'bn': 'পাক'}}},
#    'awayTeam': {'name': 'New Zealand',
#     'slug': 'new-zealand',
#     'shortName': 'NZ',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 14614,
#     'nameCode': 'NZE',
#     'class': 4,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187755,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'New Zealand',
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'न्यूज़ीलैंड',
#       'bn': 'নিউজিল্যান্ড'},
#      'shortNameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'एनज़ेड',
#       'bn': 'এনজেড'}}},
#    'homeScore': {'current': 260,
#     'display': 260,
#     'innings': {'inning1': {'score': 260,
#       'wickets': 10,
#       'overs': 47.2,
#       'runRate': 5.49,
#       'targetRunRate': 6.42}}},
#    'awayScore': {'current': 320,
#     'display': 320,
#     'innings': {'inning1': {'score': 320,
#       'wickets': 5,
#       'overs': 50,
#       'runRate': 6.4}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1739983666},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Tom Latham',
#     'slug': 'tom-latham',
#     'shortName': 'T Latham',
#     'team': {'name': 'Canterbury',
#      'slug': 'canterbury',
#      'shortName': 'CTB',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 264,
#      'nameCode': 'CAN',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 241846,
#      'country': {'alpha2': 'NZ',
#       'alpha3': 'NZL',
#       'name': 'New Zealand',
#       'slug': 'new-zealand'},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Canterbury',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'كانتربري',
#        'hi': 'कैंटरबरी',
#        'bn': 'ক্যান্টারবেরি'},
#       'shortNameTranslation': {'ar': 'كانتربري',
#        'hi': 'सीटीबी',
#        'bn': 'সিটিবি'}}},
#     'position': 'WK',
#     'jerseyNumber': '48',
#     'userCount': 33,
#     'id': 786550,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'cricketPlayerInfo': {'batting': 'Left', 'bowling': 'Right-arm medium'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'توم لاثام',
#       'hi': 'टॉम लैथम',
#       'bn': 'টম ল্যাথাম'},
#      'shortNameTranslation': {'ar': 'توم لاثام',
#       'hi': 'टॉम लैथम',
#       'bn': 'টম ল্যাথাম'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13265827,
#    'umpire1Name': 'Richard Kettleborough (ENG)',
#    'umpire2Name': 'Sharfuddoula Saikat (BAN)',
#    'tvUmpireName': 'Joel Wilson (WI)',
#    'refereeName': 'Andy Pycroft (ZIM)',
#    'tossWin': 'Pakistan',
#    'tossDecision': 'Bowling',
#    'note': 'New Zealand beat Pakistan by 60 runs',
#    'endTimestamp': 1739983620,
#    'startTimestamp': 1739955600,
#    'slug': 'new-zealand-pakistan',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'ballDetails',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13265828': {'event': {'tournament': {'name': 'ICC Champions Trophy, Group A',
#     'slug': 'icc-champions-trophy-group-a',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7149,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': True,
#     'groupName': 'Group A',
#     'competitionType': 1,
#     'isLive': False,
#     'id': 40585,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة A',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप ए',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ এ'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'UeAbspfAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'venue': {'city': {'name': 'Dubai'},
#     'hidden': True,
#     'slug': 'dubai-international-cricket-stadium-dubai',
#     'name': 'Dubai International Cricket Stadium, Dubai',
#     'id': 34629,
#     'country': {'alpha2': 'AE',
#      'alpha3': 'ARE',
#      'name': 'United Arab Emirates',
#      'slug': 'united-arab-emirates'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب دبي الدولي للكريكيت، دبي',
#       'hi': 'दुबई इंटरनेशनल क्रिकेट स्टेडियम, दुबई',
#       'bn': 'দুবাই ইন্টারন্যাশনাল ক্রিকেট স্টেডিয়াম, দুবাই'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Dubai International Cricket Stadium, Dubai'}},
#    'homeTeam': {'name': 'Bangladesh',
#     'slug': 'bangladesh',
#     'shortName': 'BAN',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 29697,
#     'venue': {'city': {'name': 'Dhaka'},
#      'hidden': True,
#      'slug': 'sher-e-bangla-national-cricket-stadium',
#      'name': 'Sher-e-Bangla National Cricket Stadium',
#      'capacity': 25416,
#      'id': 24985,
#      'country': {'alpha2': 'BD',
#       'alpha3': 'BGD',
#       'name': 'Bangladesh',
#       'slug': 'bangladesh'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب شير بنغلا الوطني للكريكيت',
#        'hi': 'शेर-ए-बांग्ला नेशनल क्रिकेट स्टेडियम',
#        'bn': 'শের-ই-বাংলা ন্যাশনাল ক্রিকেট স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Sher-e-Bangla National Cricket Stadium',
#       'capacity': 25416}},
#     'nameCode': 'BAN',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187744,
#     'country': {'alpha2': 'BD',
#      'alpha3': 'BGD',
#      'name': 'Bangladesh',
#      'slug': 'bangladesh'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Bangladesh',
#     'teamColors': {'primary': '#10a230',
#      'secondary': '#ff0000',
#      'text': '#ff0000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'بنغلاديش',
#       'hi': 'बांग्लादेश',
#       'bn': 'বাংলাদেশ'},
#      'shortNameTranslation': {'ar': 'بنغلاديش',
#       'hi': 'बीएएन',
#       'bn': 'বিএএন'}}},
#    'awayTeam': {'name': 'India',
#     'slug': 'india',
#     'shortName': 'IND',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 56782,
#     'manager': {'id': 805904,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'name': 'Gautam Gambhir',
#      'slug': 'gautam-gambhir',
#      'shortName': 'G. Gambhir'},
#     'venue': {'city': {'name': 'Mumbai'},
#      'hidden': True,
#      'slug': 'wankhede-stadium',
#      'name': 'Wankhede Stadium',
#      'capacity': 33000,
#      'id': 24773,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب وانكيدي',
#        'hi': 'वानखेड़े स्टेडियम',
#        'bn': 'ওয়াংখেড়ে স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Wankhede Stadium', 'capacity': 33000}},
#     'nameCode': 'IND',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187765,
#     'country': {'alpha2': 'IN',
#      'alpha3': 'IND',
#      'name': 'India',
#      'slug': 'india'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'India',
#     'teamColors': {'primary': '#00b8ff',
#      'secondary': '#ff4500',
#      'text': '#ff4500'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'الهند',
#       'hi': 'इंडिया',
#       'bn': 'ইন্ডিয়া'},
#      'shortNameTranslation': {'ar': 'الهند', 'hi': 'आईएनडी', 'bn': 'আইএনডি'}}},
#    'homeScore': {'current': 228,
#     'display': 228,
#     'innings': {'inning1': {'score': 228,
#       'wickets': 10,
#       'overs': 49.4,
#       'runRate': 4.59}}},
#    'awayScore': {'current': 231,
#     'display': 231,
#     'innings': {'inning1': {'score': 231,
#       'wickets': 4,
#       'overs': 46.3,
#       'runRate': 4.97,
#       'targetRunRate': 4.58}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1740068445},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Shubman Gill',
#     'slug': 'shubman-gill',
#     'shortName': 'Shubman Gill',
#     'team': {'name': 'Gujarat Titans',
#      'slug': 'gujarat-titans',
#      'shortName': 'GT',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 487,
#      'nameCode': 'GTI',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 216006,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Gujarat Titans',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'لايونز',
#        'hi': 'लायंस',
#        'bn': 'লায়ন্স'},
#       'shortNameTranslation': {'ar': 'لايونز', 'hi': 'एलआईओ', 'bn': 'এলআইও'}}},
#     'position': 'BM',
#     'jerseyNumber': '77',
#     'userCount': 1772,
#     'id': 932039,
#     'country': {'alpha2': 'IN',
#      'alpha3': 'IND',
#      'name': 'India',
#      'slug': 'india'},
#     'cricketPlayerInfo': {'batting': 'Right', 'bowling': 'Off break'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'شوبمان جيل',
#       'hi': 'शुभमन गिल',
#       'bn': 'শুভমান গিল'},
#      'shortNameTranslation': {'ar': 'شوبمان جيل',
#       'hi': 'शुभमन गिल',
#       'bn': 'শুভমান গিল'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13265828,
#    'umpire1Name': 'Adrian Holdstock (SA)',
#    'umpire2Name': 'Paul Reiffel (AUS)',
#    'tvUmpireName': 'Richard Illingworth (ENG)',
#    'refereeName': 'David Boon (AUS)',
#    'tossWin': 'Bangladesh',
#    'tossDecision': 'Batting',
#    'note': 'India beat Bangladesh by 6 wickets',
#    'endTimestamp': 1740068400,
#    'startTimestamp': 1740042000,
#    'slug': 'india-bangladesh',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'ballDetails',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13265829': {'event': {'tournament': {'name': 'ICC Champions Trophy, Group B',
#     'slug': 'icc-champions-trophy-group-b',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7149,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': True,
#     'groupName': 'Group B',
#     'competitionType': 1,
#     'isLive': False,
#     'id': 40586,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة B',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप बी',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ বি'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'AbAbsXeAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'venue': {'city': {'name': 'Karachi'},
#     'hidden': True,
#     'slug': 'national-stadium',
#     'name': 'National Stadium',
#     'capacity': 34228,
#     'id': 25028,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب الوطني',
#       'hi': 'नेशनल स्टेडियम',
#       'bn': 'ন্যাশনাল স্টেডিয়াম'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'National Stadium', 'capacity': 34228}},
#    'homeTeam': {'name': 'Afghanistan',
#     'slug': 'afghanistan',
#     'shortName': 'AFG',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 9408,
#     'venue': {'city': {'name': 'Dehra Dun, Uttarakhand'},
#      'hidden': True,
#      'slug': 'rajiv-gandhi-international-cricket-stadium',
#      'name': 'Rajiv Gandhi International Cricket Stadium',
#      'capacity': 25000,
#      'id': 24815,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب راجيف غاندي الدولي للكريكيت',
#        'hi': 'राजीव गांधी इंटरनेशनल क्रिकेट स्टेडियम',
#        'bn': 'রাজীব গান্ধী ইন্টারন্যাশনাল ক্রিকেট স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Rajiv Gandhi International Cricket Stadium',
#       'capacity': 25000}},
#     'nameCode': 'AFG',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187575,
#     'country': {'alpha2': 'AF',
#      'alpha3': 'AFG',
#      'name': 'Afghanistan',
#      'slug': 'afghanistan'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Afghanistan',
#     'teamColors': {'primary': '#ff0000',
#      'secondary': '#313131',
#      'text': '#313131'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'أفغانستان',
#       'hi': 'अफगानिस्तान',
#       'bn': 'আফগানিস্তান'},
#      'shortNameTranslation': {'ar': 'أفغانستان',
#       'hi': 'एएफजी',
#       'bn': 'এএফজি'}}},
#    'awayTeam': {'name': 'South Africa',
#     'slug': 'south-africa',
#     'shortName': 'SA',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 17361,
#     'nameCode': 'SAF',
#     'class': 4,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187747,
#     'country': {'alpha2': 'ZA',
#      'alpha3': 'ZAF',
#      'name': 'South Africa',
#      'slug': 'south-africa'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'South Africa',
#     'teamColors': {'primary': '#ffd800',
#      'secondary': '#008040',
#      'text': '#008040'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'جنوب أفريقيا',
#       'hi': 'साउथ अफ्रीका',
#       'bn': 'দক্ষিণ আফ্রিকা'},
#      'shortNameTranslation': {'ar': 'جنوب أفريقيا',
#       'hi': 'एसए',
#       'bn': 'এস.এ'}}},
#    'homeScore': {'current': 208,
#     'display': 208,
#     'innings': {'inning1': {'score': 208,
#       'wickets': 10,
#       'overs': 43.3,
#       'runRate': 4.78,
#       'targetRunRate': 6.32}}},
#    'awayScore': {'current': 315,
#     'display': 315,
#     'innings': {'inning1': {'score': 315,
#       'wickets': 6,
#       'overs': 50,
#       'runRate': 6.3}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1740155175},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Ryan Rickelton',
#     'slug': 'ryan-rickelton',
#     'shortName': 'Ryan Rickelton',
#     'team': {'name': 'Mumbai Indians',
#      'slug': 'mumbai-indians',
#      'shortName': 'MI',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 9289,
#      'venue': {'city': {'name': 'Mumbai'},
#       'hidden': True,
#       'slug': 'wankhede-stadium',
#       'name': 'Wankhede Stadium',
#       'capacity': 33006,
#       'id': 15507,
#       'country': {'alpha2': 'IN',
#        'alpha3': 'IND',
#        'name': 'India',
#        'slug': 'india'},
#       'fieldTranslations': {'nameTranslation': {'ar': 'ملعب وانكهيدي',
#         'hi': 'वानखेड़े स्टेडियम',
#         'bn': 'ওয়াংখেড়ে স্টেডিয়াম'},
#        'shortNameTranslation': {}},
#       'stadium': {'name': 'Wankhede Stadium', 'capacity': 33006}},
#      'nameCode': 'MIN',
#      'class': 1,
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 187780,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Mumbai Indians',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'مومباي إنديانز',
#        'hi': 'मुंबई इंडियंस',
#        'bn': 'মুম্বাই ইন্ডিয়ান্স'},
#       'shortNameTranslation': {'ar': 'مومباي إنديانز',
#        'hi': 'एमआई',
#        'bn': 'এমআই'}}},
#     'position': 'WK',
#     'jerseyNumber': '11',
#     'userCount': 68,
#     'id': 913437,
#     'country': {'alpha2': 'ZA',
#      'alpha3': 'ZAF',
#      'name': 'South Africa',
#      'slug': 'south-africa'},
#     'cricketPlayerInfo': {'batting': 'Left'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ريان ريكلتون',
#       'hi': 'रयान रिकेल्टन',
#       'bn': 'রায়ান রিকেল্টন'},
#      'shortNameTranslation': {'ar': 'ر ريكيلتون',
#       'hi': 'आर. रिकेल्टन',
#       'bn': 'আর রিকেল্টন'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13265829,
#    'umpire1Name': 'Alex Wharf (ENG)',
#    'umpire2Name': 'Sharfuddoula Saikat (BAN)',
#    'tvUmpireName': 'Richard Kettleborough (ENG)',
#    'refereeName': 'Ranjan Madugalle (SL)',
#    'tossWin': 'South Africa',
#    'tossDecision': 'Batting',
#    'note': 'South Africa beat Afghanistan by 107 runs',
#    'endTimestamp': 1740155100,
#    'startTimestamp': 1740128400,
#    'slug': 'south-africa-afghanistan',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'zone',
#     'angle',
#     'ballDetails',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13265830': {'event': {'tournament': {'name': 'ICC Champions Trophy, Group B',
#     'slug': 'icc-champions-trophy-group-b',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7160,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': True,
#     'groupName': 'Group B',
#     'competitionType': 1,
#     'isLive': False,
#     'id': 40586,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة B',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप बी',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ বি'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'WeAbshfAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 1,
#    'venue': {'city': {'name': 'Lahore'},
#     'hidden': True,
#     'slug': 'gaddafi-stadium',
#     'name': 'Gaddafi Stadium',
#     'capacity': 27000,
#     'id': 26886,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب القذافي',
#       'hi': 'गद्दाफी स्टेडियम',
#       'bn': 'গাদ্দাফি স্টেডিয়াম'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Gaddafi Stadium', 'capacity': 27000}},
#    'homeTeam': {'name': 'Australia',
#     'slug': 'australia',
#     'shortName': 'AUS',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 20774,
#     'nameCode': 'AUS',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187746,
#     'country': {'alpha2': 'AU',
#      'alpha3': 'AUS',
#      'name': 'Australia',
#      'slug': 'australia'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Australia',
#     'teamColors': {'primary': '#ffcc00',
#      'secondary': '#2d324b',
#      'text': '#2d324b'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'أستراليا',
#       'hi': 'ऑस्ट्रेलिया',
#       'bn': 'অস্ট্রেলিয়া'},
#      'shortNameTranslation': {'ar': 'أستراليا',
#       'hi': 'एयूएस',
#       'bn': 'এইউএস'}}},
#    'awayTeam': {'name': 'England',
#     'slug': 'england',
#     'shortName': 'ENG',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 25587,
#     'nameCode': 'ENG',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187757,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'England',
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#cc0000',
#      'text': '#cc0000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'انجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {'ar': 'انجلترا', 'hi': 'ईएनजी', 'bn': 'ইএনজি'}}},
#    'homeScore': {'current': 356,
#     'display': 356,
#     'innings': {'inning1': {'score': 356,
#       'wickets': 5,
#       'overs': 47.3,
#       'runRate': 7.49,
#       'targetRunRate': 7.04}}},
#    'awayScore': {'current': 351,
#     'display': 351,
#     'innings': {'inning1': {'score': 351,
#       'wickets': 8,
#       'overs': 50,
#       'runRate': 7.02}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1740243837},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Josh Inglis',
#     'slug': 'josh-inglis',
#     'shortName': 'Josh Inglis',
#     'team': {'name': 'Punjab Kings',
#      'slug': 'punjab-kings',
#      'shortName': 'PBKS',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 4397,
#      'venue': {'city': {'name': 'Mohali'},
#       'hidden': True,
#       'slug': 'punjab-cricket-association-stadium',
#       'name': 'Punjab Cricket Association Stadium',
#       'capacity': 30000,
#       'id': 15472,
#       'country': {'alpha2': 'IN',
#        'alpha3': 'IND',
#        'name': 'India',
#        'slug': 'india'},
#       'fieldTranslations': {'nameTranslation': {'ar': 'ملعب جمعية كريكيت البنجاب',
#         'hi': 'पंजाब क्रिकेट एसोसिएशन स्टेडियम',
#         'bn': 'পাঞ্জাব ক্রিকেট অ্যাসোসিয়েশন স্টেডিয়াম'},
#        'shortNameTranslation': {}},
#       'stadium': {'name': 'Punjab Cricket Association Stadium',
#        'capacity': 30000}},
#      'nameCode': 'PKI',
#      'class': 1,
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 187776,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Punjab Kings',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملوك البنجاب',
#        'hi': 'पंजाब किंग्स',
#        'bn': 'পাঞ্জাব কিংস'},
#       'shortNameTranslation': {'ar': 'ملوك البنجاب',
#        'hi': 'पीबीकेएस',
#        'bn': 'পিবিকেএস'}}},
#     'position': 'WK',
#     'jerseyNumber': '48',
#     'userCount': 59,
#     'id': 917346,
#     'country': {'alpha2': 'AU',
#      'alpha3': 'AUS',
#      'name': 'Australia',
#      'slug': 'australia'},
#     'cricketPlayerInfo': {'batting': 'Right'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'جوش إنجليس',
#       'hi': 'जोश इंग्लिस',
#       'bn': 'জোশ ইঙ্গলিস'},
#      'shortNameTranslation': {'ar': 'ج إنجليس',
#       'hi': 'जे. इंग्लिस',
#       'bn': 'জে ইঙ্গলিস'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13265830,
#    'umpire1Name': 'Ahsan Raza (PAK)',
#    'umpire2Name': 'Joel Wilson (WI)',
#    'tvUmpireName': 'Kumar Dharmasena (SL)',
#    'refereeName': 'Andy Pycroft (ZIM)',
#    'tossWin': 'Australia',
#    'tossDecision': 'Bowling',
#    'note': 'Australia beat England by 5 wickets',
#    'endTimestamp': 1740243780,
#    'startTimestamp': 1740214800,
#    'slug': 'england-australia',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'ballDetails',
#     'commentary',
#     'id',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13265831': {'event': {'tournament': {'name': 'ICC Champions Trophy, Group A',
#     'slug': 'icc-champions-trophy-group-a',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7149,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': True,
#     'groupName': 'Group A',
#     'competitionType': 1,
#     'isLive': False,
#     'id': 40585,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة A',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप ए',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ এ'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'efAbspfAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'venue': {'city': {'name': 'Dubai'},
#     'hidden': True,
#     'slug': 'dubai-international-cricket-stadium-dubai',
#     'name': 'Dubai International Cricket Stadium, Dubai',
#     'id': 34629,
#     'country': {'alpha2': 'AE',
#      'alpha3': 'ARE',
#      'name': 'United Arab Emirates',
#      'slug': 'united-arab-emirates'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب دبي الدولي للكريكيت، دبي',
#       'hi': 'दुबई इंटरनेशनल क्रिकेट स्टेडियम, दुबई',
#       'bn': 'দুবাই ইন্টারন্যাশনাল ক্রিকেট স্টেডিয়াম, দুবাই'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Dubai International Cricket Stadium, Dubai'}},
#    'homeTeam': {'name': 'Pakistan',
#     'slug': 'pakistan',
#     'shortName': 'PAK',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 20348,
#     'venue': {'city': {'name': 'Lahore'},
#      'hidden': True,
#      'slug': 'gaddafi-stadium',
#      'name': 'Gaddafi Stadium',
#      'capacity': 27000,
#      'id': 15542,
#      'country': {'alpha2': 'PK',
#       'alpha3': 'PAK',
#       'name': 'Pakistan',
#       'slug': 'pakistan'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب القذافي',
#        'hi': 'गद्दाफी स्टेडियम',
#        'bn': 'গাদ্দাফি স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Gaddafi Stadium', 'capacity': 27000}},
#     'nameCode': 'PAK',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187754,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Pakistan',
#     'teamColors': {'primary': '#007f4b',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'باكستان',
#       'hi': 'पाकिस्तान',
#       'bn': 'পাকিস্তান'},
#      'shortNameTranslation': {'ar': 'باكستان', 'hi': 'पीएके', 'bn': 'পাক'}}},
#    'awayTeam': {'name': 'India',
#     'slug': 'india',
#     'shortName': 'IND',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 56782,
#     'manager': {'id': 805904,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'name': 'Gautam Gambhir',
#      'slug': 'gautam-gambhir',
#      'shortName': 'G. Gambhir'},
#     'venue': {'city': {'name': 'Mumbai'},
#      'hidden': True,
#      'slug': 'wankhede-stadium',
#      'name': 'Wankhede Stadium',
#      'capacity': 33000,
#      'id': 24773,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب وانكيدي',
#        'hi': 'वानखेड़े स्टेडियम',
#        'bn': 'ওয়াংখেড়ে স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Wankhede Stadium', 'capacity': 33000}},
#     'nameCode': 'IND',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187765,
#     'country': {'alpha2': 'IN',
#      'alpha3': 'IND',
#      'name': 'India',
#      'slug': 'india'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'India',
#     'teamColors': {'primary': '#00b8ff',
#      'secondary': '#ff4500',
#      'text': '#ff4500'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'الهند',
#       'hi': 'इंडिया',
#       'bn': 'ইন্ডিয়া'},
#      'shortNameTranslation': {'ar': 'الهند', 'hi': 'आईएनडी', 'bn': 'আইএনডি'}}},
#    'homeScore': {'current': 241,
#     'display': 241,
#     'innings': {'inning1': {'score': 241,
#       'wickets': 10,
#       'overs': 49.4,
#       'runRate': 4.85}}},
#    'awayScore': {'current': 244,
#     'display': 244,
#     'innings': {'inning1': {'score': 244,
#       'wickets': 4,
#       'overs': 42.3,
#       'runRate': 5.74,
#       'targetRunRate': 4.84}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1740327445},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Virat Kohli',
#     'slug': 'virat-kohli',
#     'shortName': 'Virat Kohli',
#     'team': {'name': 'Royal Challengers Bengaluru',
#      'slug': 'royal-challengers-bengaluru',
#      'shortName': 'RCB',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 10998,
#      'venue': {'city': {'name': 'Bengaluru'},
#       'hidden': True,
#       'slug': 'm-chinnaswamy-stadium',
#       'name': 'M. Chinnaswamy Stadium',
#       'capacity': 40000,
#       'id': 15454,
#       'country': {'alpha2': 'IN',
#        'alpha3': 'IND',
#        'name': 'India',
#        'slug': 'india'},
#       'fieldTranslations': {'nameTranslation': {'ar': 'ملعب م. تشيناسوامي',
#         'hi': 'एम. चिन्नास्वामी स्टेडियम',
#         'bn': 'এম. চিন্নাস্বামী স্টেডিয়াম'},
#        'shortNameTranslation': {}},
#       'stadium': {'name': 'M. Chinnaswamy Stadium', 'capacity': 40000}},
#      'nameCode': 'RCB',
#      'class': 1,
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 187843,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Royal Challengers Bengaluru',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'رويال تشالنجرز بنغالور',
#        'hi': 'रॉयल चैलेंजर्स बैंगलोर',
#        'bn': 'রয়্যাল চ্যালেঞ্জার্স ব্যাঙ্গালোর'},
#       'shortNameTranslation': {'ar': 'رويال تشالنجرز بنغالور',
#        'hi': 'आरसीबी',
#        'bn': 'আরসিবি'}}},
#     'position': 'BM',
#     'jerseyNumber': '18',
#     'userCount': 5717,
#     'id': 786521,
#     'country': {'alpha2': 'IN',
#      'alpha3': 'IND',
#      'name': 'India',
#      'slug': 'india'},
#     'cricketPlayerInfo': {'batting': 'Right', 'bowling': 'Right-arm medium'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'فيرات كوهلي',
#       'hi': 'विराट कोहली',
#       'bn': 'ভিরাট কোহলি'},
#      'shortNameTranslation': {'ar': 'فيرات كوهلي',
#       'hi': 'विराट कोहली',
#       'bn': 'ভিরাট কোহলি'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13265831,
#    'umpire1Name': 'Paul Reiffel (AUS)',
#    'umpire2Name': 'Richard Illingworth (ENG)',
#    'tvUmpireName': 'Michael Gough (ENG)',
#    'refereeName': 'David Boon (AUS)',
#    'tossWin': 'Pakistan',
#    'tossDecision': 'Batting',
#    'note': 'India beat Pakistan by 6 wickets',
#    'endTimestamp': 1740327420,
#    'startTimestamp': 1740301200,
#    'slug': 'india-pakistan',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'ballDetails',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13265832': {'event': {'tournament': {'name': 'ICC Champions Trophy, Group A',
#     'slug': 'icc-champions-trophy-group-a',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7160,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': True,
#     'groupName': 'Group A',
#     'competitionType': 1,
#     'isLive': False,
#     'id': 40585,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة A',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप ए',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ এ'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'UeAbsffAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'venue': {'city': {'name': 'Rawalpindi'},
#     'hidden': True,
#     'slug': 'rawalpindi-cricket-stadium',
#     'name': 'Rawalpindi Cricket Stadium',
#     'capacity': 25000,
#     'id': 28111,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب كريكيت راوالبندي',
#       'hi': 'रावलपिंडी क्रिकेट स्टेडियम',
#       'bn': 'রাওয়ালপিন্ডি ক্রিকেট স্টেডিয়াম'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Rawalpindi Cricket Stadium', 'capacity': 25000}},
#    'homeTeam': {'name': 'Bangladesh',
#     'slug': 'bangladesh',
#     'shortName': 'BAN',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 29678,
#     'venue': {'city': {'name': 'Dhaka'},
#      'hidden': True,
#      'slug': 'sher-e-bangla-national-cricket-stadium',
#      'name': 'Sher-e-Bangla National Cricket Stadium',
#      'capacity': 25416,
#      'id': 24985,
#      'country': {'alpha2': 'BD',
#       'alpha3': 'BGD',
#       'name': 'Bangladesh',
#       'slug': 'bangladesh'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب شير بنغلا الوطني للكريكيت',
#        'hi': 'शेर-ए-बांग्ला नेशनल क्रिकेट स्टेडियम',
#        'bn': 'শের-ই-বাংলা ন্যাশনাল ক্রিকেট স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Sher-e-Bangla National Cricket Stadium',
#       'capacity': 25416}},
#     'nameCode': 'BAN',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187744,
#     'country': {'alpha2': 'BD',
#      'alpha3': 'BGD',
#      'name': 'Bangladesh',
#      'slug': 'bangladesh'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Bangladesh',
#     'teamColors': {'primary': '#10a230',
#      'secondary': '#ff0000',
#      'text': '#ff0000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'بنغلاديش',
#       'hi': 'बांग्लादेश',
#       'bn': 'বাংলাদেশ'},
#      'shortNameTranslation': {'ar': 'بنغلاديش',
#       'hi': 'बीएएन',
#       'bn': 'বিএএন'}}},
#    'awayTeam': {'name': 'New Zealand',
#     'slug': 'new-zealand',
#     'shortName': 'NZ',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 14614,
#     'nameCode': 'NZE',
#     'class': 4,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187755,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'New Zealand',
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'न्यूज़ीलैंड',
#       'bn': 'নিউজিল্যান্ড'},
#      'shortNameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'एनज़ेड',
#       'bn': 'এনজেড'}}},
#    'homeScore': {'current': 236,
#     'display': 236,
#     'innings': {'inning1': {'score': 236,
#       'wickets': 9,
#       'overs': 50,
#       'runRate': 4.72}}},
#    'awayScore': {'current': 240,
#     'display': 240,
#     'innings': {'inning1': {'score': 240,
#       'wickets': 5,
#       'overs': 46.1,
#       'runRate': 5.2,
#       'targetRunRate': 4.74}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1740414956},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Michael Bracewell',
#     'slug': 'michael-bracewell',
#     'shortName': 'Michael Bracewell',
#     'team': {'name': 'Southern Brave',
#      'slug': 'southern-brave',
#      'shortName': 'SOB',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 411,
#      'venue': {'city': {'name': 'Southampton'},
#       'hidden': True,
#       'slug': 'the-rose-bowl',
#       'name': 'The Rose Bowl',
#       'capacity': 6500,
#       'id': 15486,
#       'country': {'alpha2': 'EN',
#        'alpha3': 'ENG',
#        'name': 'England',
#        'slug': 'england'},
#       'fieldTranslations': {'nameTranslation': {'ar': 'ذا روز بول',
#         'hi': 'द रोज़ बाउल',
#         'bn': 'রোজ বোল'},
#        'shortNameTranslation': {}},
#       'stadium': {'name': 'The Rose Bowl', 'capacity': 6500}},
#      'nameCode': 'SBR',
#      'national': False,
#      'type': 0,
#      'id': 377177,
#      'country': {},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Southern Brave',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ساوثرن برايف',
#        'hi': 'साउथर्न ब्रेव',
#        'bn': 'সাউদার্ন ব্রেভ'},
# ...
#    'tossWin': 'Australia',
#    'tossDecision': 'Batting',
#    'note': 'India beat Australia by 4 wickets',
#    'endTimestamp': 1741104240,
#    'startTimestamp': 1741078800,
#    'slug': 'india-australia',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'ballDetails',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13558576': {'event': {'tournament': {'name': 'ICC Champions Trophy, Semi Final',
#     'slug': 'icc-champions-trophy-semi-final',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7160,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 0,
#     'isGroup': False,
#     'id': 147269,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'XeAbsffAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'venue': {'city': {'name': 'Lahore'},
#     'hidden': True,
#     'slug': 'gaddafi-stadium',
#     'name': 'Gaddafi Stadium',
#     'capacity': 27000,
#     'id': 26886,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب القذافي',
#       'hi': 'गद्दाफी स्टेडियम',
#       'bn': 'গাদ্দাফি স্টেডিয়াম'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Gaddafi Stadium', 'capacity': 27000}},
#    'homeTeam': {'name': 'South Africa',
#     'slug': 'south-africa',
#     'shortName': 'SA',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 17354,
#     'nameCode': 'SAF',
#     'class': 4,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187747,
#     'country': {'alpha2': 'ZA',
#      'alpha3': 'ZAF',
#      'name': 'South Africa',
#      'slug': 'south-africa'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'South Africa',
#     'teamColors': {'primary': '#ffd800',
#      'secondary': '#008040',
#      'text': '#008040'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'جنوب أفريقيا',
#       'hi': 'साउथ अफ्रीका',
#       'bn': 'দক্ষিণ আফ্রিকা'},
#      'shortNameTranslation': {'ar': 'جنوب أفريقيا',
#       'hi': 'एसए',
#       'bn': 'এস.এ'}}},
#    'awayTeam': {'name': 'New Zealand',
#     'slug': 'new-zealand',
#     'shortName': 'NZ',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 14614,
#     'nameCode': 'NZE',
#     'class': 4,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187755,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'New Zealand',
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'न्यूज़ीलैंड',
#       'bn': 'নিউজিল্যান্ড'},
#      'shortNameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'एनज़ेड',
#       'bn': 'এনজেড'}}},
#    'homeScore': {'current': 312,
#     'display': 312,
#     'innings': {'inning1': {'score': 312,
#       'wickets': 9,
#       'overs': 50,
#       'runRate': 6.24,
#       'targetRunRate': 7.26}}},
#    'awayScore': {'current': 362,
#     'display': 362,
#     'innings': {'inning1': {'score': 362,
#       'wickets': 6,
#       'overs': 50,
#       'runRate': 7.24}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1741193481},
#    'hasGlobalHighlights': True,
#    'manOfMatch': {'name': 'Rachin Ravindra',
#     'slug': 'rachin-ravindra',
#     'shortName': 'Rachin Ravindra',
#     'team': {'name': 'Manchester Originals',
#      'slug': 'manchester-originals',
#      'shortName': 'MNR',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 464,
#      'nameCode': 'MOR',
#      'national': False,
#      'type': 0,
#      'id': 377173,
#      'country': {},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Manchester Originals',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'مانشستر أوريجينالز',
#        'hi': 'मैनचेस्टर ओरिजिनल्स',
#        'bn': 'ম্যানচেস্টার অরিজিনালস'},
#       'shortNameTranslation': {'ar': 'مانشستر أوريجينالز',
#        'hi': 'एमएनआर',
#        'bn': 'এমএনআর'}}},
#     'position': 'AR',
#     'jerseyNumber': '8',
#     'userCount': 260,
#     'id': 974426,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'cricketPlayerInfo': {'batting': 'Left',
#      'bowling': 'Slow left-arm orthodox'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'راشين رافيندرا',
#       'hi': 'रचिन रविन्द्र',
#       'bn': 'রচিন রবীন্দ্র'},
#      'shortNameTranslation': {'ar': 'راشين رافيندرا',
#       'hi': 'रचिन रविन्द्र',
#       'bn': 'রচিন রবীন্দ্র'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13558576,
#    'umpire1Name': 'Kumar Dharmasena (SL)',
#    'umpire2Name': 'Paul Reiffel (AUS)',
#    'tvUmpireName': 'Joel Wilson (WI)',
#    'refereeName': 'Ranjan Madugalle (SL)',
#    'tossWin': 'New Zealand',
#    'tossDecision': 'Batting',
#    'note': 'New Zealand beat South Africa by 50 runs',
#    'endTimestamp': 1741193460,
#    'startTimestamp': 1741165200,
#    'slug': 'new-zealand-south-africa',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'ballDetails',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}},
#  'match_details_13569002': {'event': {'tournament': {'name': 'ICC Champions Trophy, Final',
#     'slug': 'icc-champions-trophy-final',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'uniqueTournament': {'name': 'ICC Champions Trophy',
#      'slug': 'icc-champions-trophy',
#      'primaryColorHex': '#b0885b',
#      'secondaryColorHex': '#928a85',
#      'category': {'id': 1343,
#       'country': {},
#       'name': 'World',
#       'slug': 'world',
#       'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#       'flag': 'international',
#       'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#         'hi': 'विश्व',
#         'bn': 'বিশ্ব'},
#        'shortNameTranslation': {}}},
#      'userCount': 7160,
#      'id': 11181,
#      'country': {},
#      'hasPerformanceGraphFeature': False,
#      'hasEventPlayerStatistics': False,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#        'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#        'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#       'shortNameTranslation': {}}},
#     'priority': 18,
#     'isGroup': False,
#     'id': 147429,
#     'endTimestamp': 1741478400,
#     'startTimestamp': 1739923200},
#    'season': {'name': 'ICC Champions Trophy, 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70172},
#    'customId': 'ffAbspfAb',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 1,
#    'venue': {'city': {'name': 'Dubai'},
#     'hidden': True,
#     'slug': 'dubai-international-cricket-stadium-dubai',
#     'name': 'Dubai International Cricket Stadium, Dubai',
#     'id': 34629,
#     'country': {'alpha2': 'AE',
#      'alpha3': 'ARE',
#      'name': 'United Arab Emirates',
#      'slug': 'united-arab-emirates'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب دبي الدولي للكريكيت، دبي',
#       'hi': 'दुबई इंटरनेशनल क्रिकेट स्टेडियम, दुबई',
#       'bn': 'দুবাই ইন্টারন্যাশনাল ক্রিকেট স্টেডিয়াম, দুবাই'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Dubai International Cricket Stadium, Dubai'}},
#    'homeTeam': {'name': 'India',
#     'slug': 'india',
#     'shortName': 'IND',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 56772,
#     'manager': {'id': 805904,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'name': 'Gautam Gambhir',
#      'slug': 'gautam-gambhir',
#      'shortName': 'G. Gambhir'},
#     'venue': {'city': {'name': 'Mumbai'},
#      'hidden': True,
#      'slug': 'wankhede-stadium',
#      'name': 'Wankhede Stadium',
#      'capacity': 33000,
#      'id': 24773,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ملعب وانكيدي',
#        'hi': 'वानखेड़े स्टेडियम',
#        'bn': 'ওয়াংখেড়ে স্টেডিয়াম'},
#       'shortNameTranslation': {}},
#      'stadium': {'name': 'Wankhede Stadium', 'capacity': 33000}},
#     'nameCode': 'IND',
#     'class': 1,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187765,
#     'country': {'alpha2': 'IN',
#      'alpha3': 'IND',
#      'name': 'India',
#      'slug': 'india'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'India',
#     'teamColors': {'primary': '#00b8ff',
#      'secondary': '#ff4500',
#      'text': '#ff4500'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'الهند',
#       'hi': 'इंडिया',
#       'bn': 'ইন্ডিয়া'},
#      'shortNameTranslation': {'ar': 'الهند', 'hi': 'आईएनडी', 'bn': 'আইএনডি'}}},
#    'awayTeam': {'name': 'New Zealand',
#     'slug': 'new-zealand',
#     'shortName': 'NZ',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 14614,
#     'nameCode': 'NZE',
#     'class': 4,
#     'disabled': False,
#     'national': True,
#     'type': 0,
#     'id': 187755,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'New Zealand',
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'न्यूज़ीलैंड',
#       'bn': 'নিউজিল্যান্ড'},
#      'shortNameTranslation': {'ar': 'نيوزيلندا',
#       'hi': 'एनज़ेड',
#       'bn': 'এনজেড'}}},
#    'homeScore': {'current': 254,
#     'display': 254,
#     'innings': {'inning1': {'score': 254,
#       'wickets': 6,
#       'overs': 49,
#       'runRate': 5.18,
#       'targetRunRate': 5.04}}},
#    'awayScore': {'current': 251,
#     'display': 251,
#     'innings': {'inning1': {'score': 251,
#       'wickets': 7,
#       'overs': 50,
#       'runRate': 5.02}}},
#    'coverage': 1,
#    'time': {},
#    'changes': {'changes': ['status.code',
#      'status.description',
#      'status.type',
#      'homeScore.current',
#      'homeScore.display',
#      'homeScore.innings'],
#     'changeTimestamp': 1741537113},
#    'hasGlobalHighlights': False,
#    'manOfMatch': {'name': 'Rohit Sharma',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'rohit-sharma',
#     'shortName': 'Rohit Sharma',
#     'team': {'name': 'Mumbai Indians',
#      'slug': 'mumbai-indians',
#      'shortName': 'MI',
#      'gender': 'M',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'userCount': 9274,
#      'venue': {'city': {'name': 'Mumbai'},
#       'hidden': True,
#       'slug': 'wankhede-stadium',
#       'name': 'Wankhede Stadium',
#       'capacity': 33006,
#       'id': 15507,
#       'country': {'alpha2': 'IN',
#        'alpha3': 'IND',
#        'name': 'India',
#        'slug': 'india'},
#       'fieldTranslations': {'nameTranslation': {'ar': 'ملعب وانكهيدي',
#         'hi': 'वानखेड़े स्टेडियम',
#         'bn': 'ওয়াংখেড়ে স্টেডিয়াম'},
#        'shortNameTranslation': {}},
#       'stadium': {'name': 'Wankhede Stadium', 'capacity': 33006}},
#      'nameCode': 'MIN',
#      'class': 1,
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 187780,
#      'country': {'alpha2': 'IN',
#       'alpha3': 'IND',
#       'name': 'India',
#       'slug': 'india'},
#      'entityType': 'team',
#      'subTeams': [],
#      'fullName': 'Mumbai Indians',
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'مومباي إنديانز',
#        'hi': 'मुंबई इंडियंस',
#        'bn': 'মুম্বাই ইন্ডিয়ান্স'},
#       'shortNameTranslation': {'ar': 'مومباي إنديانز',
#        'hi': 'एमआई',
#        'bn': 'এমআই'}}},
#     'position': 'BM',
#     'jerseyNumber': '45',
#     'userCount': 3434,
#     'id': 786520,
#     'country': {'alpha2': 'IN',
#      'alpha3': 'IND',
#      'name': 'India',
#      'slug': 'india'},
#     'cricketPlayerInfo': {'batting': 'Right', 'bowling': 'Off break'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'روهيت شارما',
#       'hi': 'रोहित शर्मा',
#       'bn': 'রোহিত শর্মা'},
#      'shortNameTranslation': {'ar': 'روهيت شارما',
#       'hi': 'रोहित शर्मा',
#       'bn': 'রোহিত শর্মা'}}},
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13569002,
#    'umpire1Name': 'Paul Reiffel (AUS)',
#    'umpire2Name': 'Richard Illingworth (ENG)',
#    'tvUmpireName': 'Joel Wilson (WI)',
#    'refereeName': 'Ranjan Madugalle (SL)',
#    'tossWin': 'New Zealand',
#    'tossDecision': 'Batting',
#    'note': 'India beat New Zealand by 4 wickets',
#    'endTimestamp': 1741537080,
#    'startTimestamp': 1741510800,
#    'slug': 'india-new-zealand',
#    'periods': {'current': 'Match',
#     'inning1': '1st Inning',
#     'inning2': '2nd Inning',
#     'inning3': '3rd Inning',
#     'inning4': '4th Inning'},
#    'finalResultOnly': False,
#    'feedLocked': False,
#    'cricketBallProperties': ['time',
#     'number',
#     'over',
#     'ball',
#     'runs',
#     'score',
#     'scored',
#     'wicket',
#     'missed',
#     'incidentClassLabel',
#     'incidentClassColor',
#     'batsman',
#     'bowler',
#     'commentary',
#     'id',
#     'ballDetails',
#     'zone',
#     'angle',
#     'bowlDetail',
#     'fielder'],
#    'fanRatingEvent': False,
#    'showTotoPromo': True,
#    'isEditor': False}}}

# %%
data.keys()
# Out:
# dict_keys(['match_details_13265827', 'match_details_13265828', 'match_details_13265829', 'match_details_13265830', 'match_details_13265831', 'match_details_13265832', 'match_details_13265833', 'match_details_13265834', 'match_details_13265836', 'match_details_13265837', 'match_details_13265838', 'match_details_13265840', 'match_details_13558575', 'match_details_13558576', 'match_details_13569002'])

# %% [markdown]
# # Depth json to flatten_json

# %%
# Function for Convert a nested json dictionary to flatten json or dictionary
def flatten_json(nested_json, parent_key='', sep='_'):

    items = []
    
    # If the value is a dictionary
    if isinstance(nested_json, dict):
        for key, value in nested_json.items():
            new_key = f"{parent_key}{sep}{key}" if parent_key else key
            items.extend(flatten_json(value, new_key, sep=sep).items())
    
    # If the value is a list
    elif isinstance(nested_json, list): 
        for index, item in enumerate(nested_json):
            new_key = f"{parent_key}{sep}{index}" if parent_key else str(index)
            items.extend(flatten_json(item, new_key, sep=sep).items())
            
    # If the value is neither dict nor list
    else:
        items.append((parent_key, nested_json))

    return dict(items)

# %% [markdown]
# # Flatten Json to Row column

# %%
def process_json_file(data):
    try:
        # Normalize JSON data
        if isinstance(data, list):  # JSON is an array of objects
            flat_data = [flatten_json(item) for item in data]
        elif isinstance(data, dict):  # JSON is a single dictionary
            flat_data = [flatten_json(data)]
        else:
            raise ValueError("Unsupported JSON format")

        # Convert to DataFrame
        df = pd.DataFrame(flat_data)
        return df


    except json.JSONDecodeError:
        print("Error: Invalid JSON file.")
    except Exception as e:
        print(f"Error: {str(e)}")

# %% [markdown]
# ## 1. first level keys

# %%
# first level keys
print("Data Type: ", type(data))
data.keys()
# Out:
# Data Type:  <class 'dict'>
# dict_keys(['match_details_13265827', 'match_details_13265828', 'match_details_13265829', 'match_details_13265830', 'match_details_13265831', 'match_details_13265832', 'match_details_13265833', 'match_details_13265834', 'match_details_13265836', 'match_details_13265837', 'match_details_13265838', 'match_details_13265840', 'match_details_13558575', 'match_details_13558576', 'match_details_13569002'])

# %% [markdown]
# ## 2. second level keys

# %% [markdown]
# # Dictionary to Row data

# %%
def process_dictionary(data):
    all_dataframe = {}
    parent_json = {}

    for key in data:
        if data[key] is not None and data[key] != "" and data[key] != {}:
            if isinstance(data[key], list):  # If value is a list
                dataframe = pd.DataFrame(columns=process_json_file(flatten_json(data[key][0])).columns)
                for i in range(len(data[key])):
                    flatten_dict = flatten_json(data[key][i])
                    new_dataframe = process_json_file(flatten_dict)
                    dataframe = pd.concat([dataframe, new_dataframe], ignore_index=True)

                    # Deleting field translation columns
                    dataframe = dataframe.loc[:, ~dataframe.columns.str.contains("fieldtranslations|translation", case=False, regex=True)]

                if dataframe.shape[1] >= 10:  # If columns are 10 or more
                    all_dataframe[key] = dataframe
                else:
                    parent_json[key] = data[key]

            elif isinstance(data[key], dict):  # If value is a dictionary
                flatten_dict = flatten_json(data[key])
                dataframe = process_json_file(flatten_dict)

                # Deleting field translation columns
                dataframe = dataframe.loc[:, ~dataframe.columns.str.contains("fieldtranslations|translation", case=False, regex=True)]

                if dataframe.shape[1] >= 10:  # If columns are 5 or more
                    all_dataframe[key] = dataframe
                else:
                    parent_json[key] = data[key]
            else:
                parent_json[key] = data[key]

    # Convert parent_json into a DataFrame and store it in all_dataframe
    all_dataframe["parent_df"] = process_json_file(flatten_json(parent_json))

    return all_dataframe

# %%
data.keys()
# Out:
# dict_keys(['match_details_13265827', 'match_details_13265828', 'match_details_13265829', 'match_details_13265830', 'match_details_13265831', 'match_details_13265832', 'match_details_13265833', 'match_details_13265834', 'match_details_13265836', 'match_details_13265837', 'match_details_13265838', 'match_details_13265840', 'match_details_13558575', 'match_details_13558576', 'match_details_13569002'])

# %%
data['match_details_13265827']
# Out:
# {'event': {'tournament': {'name': 'ICC Champions Trophy, Group A',
#    'slug': 'icc-champions-trophy-group-a',
#    'category': {'id': 1343,
#     'country': {},
#     'name': 'World',
#     'slug': 'world',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'flag': 'international',
#     'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#       'hi': 'विश्व',
#       'bn': 'বিশ্ব'},
#      'shortNameTranslation': {}}},
#    'uniqueTournament': {'name': 'ICC Champions Trophy',
#     'slug': 'icc-champions-trophy',
#     'primaryColorHex': '#b0885b',
#     'secondaryColorHex': '#928a85',
#     'category': {'id': 1343,
#      'country': {},
#      'name': 'World',
#      'slug': 'world',
#      'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#      'flag': 'international',
#      'fieldTranslations': {'nameTranslation': {'ar': 'العالم',
#        'hi': 'विश्व',
#        'bn': 'বিশ্ব'},
#       'shortNameTranslation': {}}},
#     'userCount': 7160,
#     'id': 11181,
#     'country': {},
#     'hasPerformanceGraphFeature': False,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال ICC',
#       'hi': 'आईसीसी चैंपियंस ट्रॉफी',
#       'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি'},
#      'shortNameTranslation': {}}},
#    'priority': 0,
#    'isGroup': True,
#    'groupName': 'Group A',
#    'competitionType': 1,
#    'isLive': False,
#    'id': 40585,
#    'endTimestamp': 1741478400,
#    'startTimestamp': 1739923200,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كأس أبطال مجلس الكريكيت الدولي، المجموعة A',
#      'hi': 'आईसीसी चैंपियंस ट्रॉफी, ग्रुप ए',
#      'bn': 'আইসিসি চ্যাম্পিয়ন্স ট্রফি, গ্রুপ এ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'ICC Champions Trophy, 2025',
#    'year': '2025',
#    'editor': False,
#    'id': 70172},
#   'customId': 'efAbsffAb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'venue': {'city': {'name': 'Karachi'},
#    'hidden': True,
#    'slug': 'national-stadium',
#    'name': 'National Stadium',
#    'capacity': 34228,
#    'id': 25028,
#    'country': {'alpha2': 'PK',
#     'alpha3': 'PAK',
#     'name': 'Pakistan',
#     'slug': 'pakistan'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ملعب الوطني',
#      'hi': 'नेशनल स्टेडियम',
#      'bn': 'ন্যাশনাল স্টেডিয়াম'},
#     'shortNameTranslation': {}},
#    'stadium': {'name': 'National Stadium', 'capacity': 34228}},
#   'homeTeam': {'name': 'Pakistan',
#    'slug': 'pakistan',
#    'shortName': 'PAK',
#    'gender': 'M',
#    'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#    'userCount': 20334,
#    'venue': {'city': {'name': 'Lahore'},
#     'hidden': True,
#     'slug': 'gaddafi-stadium',
#     'name': 'Gaddafi Stadium',
#     'capacity': 27000,
#     'id': 15542,
#     'country': {'alpha2': 'PK',
#      'alpha3': 'PAK',
#      'name': 'Pakistan',
#      'slug': 'pakistan'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ملعب القذافي',
#       'hi': 'गद्दाफी स्टेडियम',
#       'bn': 'গাদ্দাফি স্টেডিয়াম'},
#      'shortNameTranslation': {}},
#     'stadium': {'name': 'Gaddafi Stadium', 'capacity': 27000}},
#    'nameCode': 'PAK',
#    'class': 1,
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 187754,
#    'country': {'alpha2': 'PK',
#     'alpha3': 'PAK',
#     'name': 'Pakistan',
#     'slug': 'pakistan'},
#    'entityType': 'team',
#    'subTeams': [],
#    'fullName': 'Pakistan',
#    'teamColors': {'primary': '#007f4b',
#     'secondary': '#ffffff',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'باكستان',
#      'hi': 'पाकिस्तान',
#      'bn': 'পাকিস্তান'},
#     'shortNameTranslation': {'ar': 'باكستان', 'hi': 'पीएके', 'bn': 'পাক'}}},
#   'awayTeam': {'name': 'New Zealand',
#    'slug': 'new-zealand',
#    'shortName': 'NZ',
#    'gender': 'M',
#    'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#    'userCount': 14614,
#    'nameCode': 'NZE',
#    'class': 4,
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 187755,
#    'country': {'alpha2': 'NZ',
#     'alpha3': 'NZL',
#     'name': 'New Zealand',
#     'slug': 'new-zealand'},
#    'entityType': 'team',
#    'subTeams': [],
#    'fullName': 'New Zealand',
#    'teamColors': {'primary': '#ffffff',
#     'secondary': '#000000',
#     'text': '#000000'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيوزيلندا',
#      'hi': 'न्यूज़ीलैंड',
#      'bn': 'নিউজিল্যান্ড'},
#     'shortNameTranslation': {'ar': 'نيوزيلندا',
#      'hi': 'एनज़ेड',
#      'bn': 'এনজেড'}}},
#   'homeScore': {'current': 260,
#    'display': 260,
#    'innings': {'inning1': {'score': 260,
#      'wickets': 10,
#      'overs': 47.2,
#      'runRate': 5.49,
#      'targetRunRate': 6.42}}},
#   'awayScore': {'current': 320,
#    'display': 320,
#    'innings': {'inning1': {'score': 320,
#      'wickets': 5,
#      'overs': 50,
#      'runRate': 6.4}}},
#   'coverage': 1,
#   'time': {},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1739983666},
#   'hasGlobalHighlights': True,
#   'manOfMatch': {'name': 'Tom Latham',
#    'slug': 'tom-latham',
#    'shortName': 'T Latham',
#    'team': {'name': 'Canterbury',
#     'slug': 'canterbury',
#     'shortName': 'CTB',
#     'gender': 'M',
#     'sport': {'name': 'Cricket', 'slug': 'cricket', 'id': 62},
#     'userCount': 264,
#     'nameCode': 'CAN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 241846,
#     'country': {'alpha2': 'NZ',
#      'alpha3': 'NZL',
#      'name': 'New Zealand',
#      'slug': 'new-zealand'},
#     'entityType': 'team',
#     'subTeams': [],
#     'fullName': 'Canterbury',
#     'teamColors': {'primary': '#374df5',
#      'secondary': '#374df5',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'كانتربري',
#       'hi': 'कैंटरबरी',
#       'bn': 'ক্যান্টারবেরি'},
#      'shortNameTranslation': {'ar': 'كانتربري',
#       'hi': 'सीटीबी',
#       'bn': 'সিটিবি'}}},
#    'position': 'WK',
#    'jerseyNumber': '48',
#    'userCount': 33,
#    'id': 786550,
#    'country': {'alpha2': 'NZ',
#     'alpha3': 'NZL',
#     'name': 'New Zealand',
#     'slug': 'new-zealand'},
#    'cricketPlayerInfo': {'batting': 'Left', 'bowling': 'Right-arm medium'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'توم لاثام',
#      'hi': 'टॉम लैथम',
#      'bn': 'টম ল্যাথাম'},
#     'shortNameTranslation': {'ar': 'توم لاثام',
#      'hi': 'टॉम लैथम',
#      'bn': 'টম ল্যাথাম'}}},
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 13265827,
#   'umpire1Name': 'Richard Kettleborough (ENG)',
#   'umpire2Name': 'Sharfuddoula Saikat (BAN)',
#   'tvUmpireName': 'Joel Wilson (WI)',
#   'refereeName': 'Andy Pycroft (ZIM)',
#   'tossWin': 'Pakistan',
#   'tossDecision': 'Bowling',
#   'note': 'New Zealand beat Pakistan by 60 runs',
#   'endTimestamp': 1739983620,
#   'startTimestamp': 1739955600,
#   'slug': 'new-zealand-pakistan',
#   'periods': {'current': 'Match',
#    'inning1': '1st Inning',
#    'inning2': '2nd Inning',
#    'inning3': '3rd Inning',
#    'inning4': '4th Inning'},
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'cricketBallProperties': ['time',
#    'number',
#    'over',
#    'ball',
#    'runs',
#    'score',
#    'scored',
#    'wicket',
#    'missed',
#    'incidentClassLabel',
#    'incidentClassColor',
#    'batsman',
#    'bowler',
#    'commentary',
#    'id',
#    'ballDetails',
#    'zone',
#    'angle',
#    'bowlDetail',
#    'fielder'],
#   'fanRatingEvent': False,
#   'showTotoPromo': True,
#   'isEditor': False}}

# %%
all_dataframe = process_dictionary(data['match_details_13265827'])

# %%
champ_trophy_match_details = pd.DataFrame(columns=process_dictionary(data[list(data.keys())[0]])['event'].columns)
champ_trophy_match_details
# Out:
# Empty DataFrame
# Columns: [tournament_name, tournament_slug, tournament_category_id, tournament_category_name, tournament_category_slug, tournament_category_sport_name, tournament_category_sport_slug, tournament_category_sport_id, tournament_category_flag, tournament_uniqueTournament_name, tournament_uniqueTournament_slug, tournament_uniqueTournament_primaryColorHex, tournament_uniqueTournament_secondaryColorHex, tournament_uniqueTournament_category_id, tournament_uniqueTournament_category_name, tournament_uniqueTournament_category_slug, tournament_uniqueTournament_category_sport_name, tournament_uniqueTournament_category_sport_slug, tournament_uniqueTournament_category_sport_id, tournament_uniqueTournament_category_flag, tournament_uniqueTournament_userCount, tournament_uniqueTournament_id, tournament_uniqueTournament_hasPerformanceGraphFeature, tournament_uniqueTournament_hasEventPlayerStatistics, tournament_uniqueTournament_displayInverseHomeAwayTeams, tournament_priority, tournament_isGroup, tournament_groupName, tournament_competitionType, tournament_isLive, tournament_id, tournament_endTimestamp, tournament_startTimestamp, season_name, season_year, season_editor, season_id, customId, status_code, status_description, status_type, winnerCode, venue_city_name, venue_hidden, venue_slug, venue_name, venue_capacity, venue_id, venue_country_alpha2, venue_country_alpha3, venue_country_name, venue_country_slug, venue_stadium_name, venue_stadium_capacity, homeTeam_name, homeTeam_slug, homeTeam_shortName, homeTeam_gender, homeTeam_sport_name, homeTeam_sport_slug, homeTeam_sport_id, homeTeam_userCount, homeTeam_venue_city_name, homeTeam_venue_hidden, homeTeam_venue_slug, homeTeam_venue_name, homeTeam_venue_capacity, homeTeam_venue_id, homeTeam_venue_country_alpha2, homeTeam_venue_country_alpha3, homeTeam_venue_country_name, homeTeam_venue_country_slug, homeTeam_venue_stadium_name, homeTeam_venue_stadium_capacity, homeTeam_nameCode, homeTeam_class, homeTeam_disabled, homeTeam_national, homeTeam_type, homeTeam_id, homeTeam_country_alpha2, homeTeam_country_alpha3, homeTeam_country_name, homeTeam_country_slug, homeTeam_entityType, homeTeam_fullName, homeTeam_teamColors_primary, homeTeam_teamColors_secondary, homeTeam_teamColors_text, awayTeam_name, awayTeam_slug, awayTeam_shortName, awayTeam_gender, awayTeam_sport_name, awayTeam_sport_slug, awayTeam_sport_id, awayTeam_userCount, awayTeam_nameCode, awayTeam_class, awayTeam_disabled, ...]
# Index: []
#
# [0 rows x 208 columns]

# %%
champ_trophy_match_details
# Out:
# Empty DataFrame
# Columns: [tournament_name, tournament_slug, tournament_category_id, tournament_category_name, tournament_category_slug, tournament_category_sport_name, tournament_category_sport_slug, tournament_category_sport_id, tournament_category_flag, tournament_uniqueTournament_name, tournament_uniqueTournament_slug, tournament_uniqueTournament_primaryColorHex, tournament_uniqueTournament_secondaryColorHex, tournament_uniqueTournament_category_id, tournament_uniqueTournament_category_name, tournament_uniqueTournament_category_slug, tournament_uniqueTournament_category_sport_name, tournament_uniqueTournament_category_sport_slug, tournament_uniqueTournament_category_sport_id, tournament_uniqueTournament_category_flag, tournament_uniqueTournament_userCount, tournament_uniqueTournament_id, tournament_uniqueTournament_hasPerformanceGraphFeature, tournament_uniqueTournament_hasEventPlayerStatistics, tournament_uniqueTournament_displayInverseHomeAwayTeams, tournament_priority, tournament_isGroup, tournament_groupName, tournament_competitionType, tournament_isLive, tournament_id, tournament_endTimestamp, tournament_startTimestamp, season_name, season_year, season_editor, season_id, customId, status_code, status_description, status_type, winnerCode, venue_city_name, venue_hidden, venue_slug, venue_name, venue_capacity, venue_id, venue_country_alpha2, venue_country_alpha3, venue_country_name, venue_country_slug, venue_stadium_name, venue_stadium_capacity, homeTeam_name, homeTeam_slug, homeTeam_shortName, homeTeam_gender, homeTeam_sport_name, homeTeam_sport_slug, homeTeam_sport_id, homeTeam_userCount, homeTeam_venue_city_name, homeTeam_venue_hidden, homeTeam_venue_slug, homeTeam_venue_name, homeTeam_venue_capacity, homeTeam_venue_id, homeTeam_venue_country_alpha2, homeTeam_venue_country_alpha3, homeTeam_venue_country_name, homeTeam_venue_country_slug, homeTeam_venue_stadium_name, homeTeam_venue_stadium_capacity, homeTeam_nameCode, homeTeam_class, homeTeam_disabled, homeTeam_national, homeTeam_type, homeTeam_id, homeTeam_country_alpha2, homeTeam_country_alpha3, homeTeam_country_name, homeTeam_country_slug, homeTeam_entityType, homeTeam_fullName, homeTeam_teamColors_primary, homeTeam_teamColors_secondary, homeTeam_teamColors_text, awayTeam_name, awayTeam_slug, awayTeam_shortName, awayTeam_gender, awayTeam_sport_name, awayTeam_sport_slug, awayTeam_sport_id, awayTeam_userCount, awayTeam_nameCode, awayTeam_class, awayTeam_disabled, ...]
# Index: []
#
# [0 rows x 208 columns]

# %%
for i in data.keys():
    match_data = process_dictionary(data[i])['event']
    champ_trophy_match_details = pd.concat([champ_trophy_match_details, match_data])
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_1768\2246210733.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   champ_trophy_match_details = pd.concat([champ_trophy_match_details, match_data])

# %%
champ_trophy_match_details
# Out:
#                     tournament_name                  tournament_slug  \
# 0     ICC Champions Trophy, Group A     icc-champions-trophy-group-a
# 0     ICC Champions Trophy, Group A     icc-champions-trophy-group-a
# 0     ICC Champions Trophy, Group B     icc-champions-trophy-group-b
# 0     ICC Champions Trophy, Group B     icc-champions-trophy-group-b
# 0     ICC Champions Trophy, Group A     icc-champions-trophy-group-a
# 0     ICC Champions Trophy, Group A     icc-champions-trophy-group-a
# 0     ICC Champions Trophy, Group B     icc-champions-trophy-group-b
# 0     ICC Champions Trophy, Group B     icc-champions-trophy-group-b
# 0     ICC Champions Trophy, Group A     icc-champions-trophy-group-a
# 0     ICC Champions Trophy, Group B     icc-champions-trophy-group-b
# 0     ICC Champions Trophy, Group B     icc-champions-trophy-group-b
# 0     ICC Champions Trophy, Group A     icc-champions-trophy-group-a
# 0  ICC Champions Trophy, Semi Final  icc-champions-trophy-semi-final
# 0  ICC Champions Trophy, Semi Final  icc-champions-trophy-semi-final
# 0       ICC Champions Trophy, Final       icc-champions-trophy-final
#
#   tournament_category_id tournament_category_name tournament_category_slug  \
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
# 0                   1343                    World                    world
#
#   tournament_category_sport_name tournament_category_sport_slug  \
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
# 0                        Cricket                        cricket
#
#   tournament_category_sport_id tournament_category_flag  \
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
# 0                           62            international
#
#   tournament_uniqueTournament_name  ... manOfMatch_firstName  \
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...                  NaN
# 0             ICC Champions Trophy  ...
#
#   manOfMatch_lastName homeTeam_manager_id homeTeam_manager_country_alpha2  \
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                                     NaN                             NaN
# 0                 NaN                 NaN                             NaN
# 0                 NaN            805904.0                              IN
# 0                 NaN                 NaN                             NaN
# 0                                805904.0                              IN
#
#   homeTeam_manager_country_alpha3 homeTeam_manager_country_name  \
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             NaN                           NaN
# 0                             IND                         India
# 0                             NaN                           NaN
# 0                             IND                         India
#
#   homeTeam_manager_country_slug homeTeam_manager_name homeTeam_manager_slug  \
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                           NaN                   NaN                   NaN
# 0                         india        Gautam Gambhir        gautam-gambhir
# 0                           NaN                   NaN                   NaN
# 0                         india        Gautam Gambhir        gautam-gambhir
#
#   homeTeam_manager_shortName
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                 G. Gambhir
# 0                        NaN
# 0                 G. Gambhir
#
# [15 rows x 255 columns]

# %%
champ_trophy_match_details.to_excel('champ_trophy_match_details.xlsx', index=False)

# %%
process_dictionary(data[i])['event']

# %%
match_data = process_dictionary(data['match_details_13265827'])['event']
match_data
# Out:
#                  tournament_name               tournament_slug  \
# 0  ICC Champions Trophy, Group A  icc-champions-trophy-group-a
#
#    tournament_category_id tournament_category_name tournament_category_slug  \
# 0                    1343                    World                    world
#
#   tournament_category_sport_name tournament_category_sport_slug  \
# 0                        Cricket                        cricket
#
#    tournament_category_sport_id tournament_category_flag  \
# 0                            62            international
#
#   tournament_uniqueTournament_name  ... cricketBallProperties_13  \
# 0             ICC Champions Trophy  ...               commentary
#
#   cricketBallProperties_14 cricketBallProperties_15  cricketBallProperties_16  \
# 0                       id              ballDetails                      zone
#
#   cricketBallProperties_17 cricketBallProperties_18 cricketBallProperties_19  \
# 0                    angle               bowlDetail                  fielder
#
#   fanRatingEvent  showTotoPromo isEditor
# 0          False           True    False
#
# [1 rows x 208 columns]

# %%
all_dataframe['event']
# Out:
#                tournament_name             tournament_slug  \
# 0  ICC Champions Trophy, Final  icc-champions-trophy-final
#
#    tournament_category_id tournament_category_name tournament_category_slug  \
# 0                    1343                    World                    world
#
#   tournament_category_sport_name tournament_category_sport_slug  \
# 0                        Cricket                        cricket
#
#    tournament_category_sport_id tournament_category_flag  \
# 0                            62            international
#
#   tournament_uniqueTournament_name  ... cricketBallProperties_13  \
# 0             ICC Champions Trophy  ...               commentary
#
#   cricketBallProperties_14 cricketBallProperties_15  cricketBallProperties_16  \
# 0                       id              ballDetails                      zone
#
#   cricketBallProperties_17 cricketBallProperties_18 cricketBallProperties_19  \
# 0                    angle               bowlDetail                  fielder
#
#   fanRatingEvent  showTotoPromo isEditor
# 0          False           True    False
#
# [1 rows x 229 columns]

# %%
all_dataframe['event'].to_excel("match_details.xlsx", index=False)

# %%
data['event'].keys()
# Out:
# dict_keys(['tournament', 'season', 'customId', 'status', 'winnerCode', 'venue', 'homeTeam', 'awayTeam', 'homeScore', 'awayScore', 'coverage', 'time', 'changes', 'hasGlobalHighlights', 'manOfMatch', 'crowdsourcingDataDisplayEnabled', 'id', 'umpire1Name', 'umpire2Name', 'tvUmpireName', 'refereeName', 'tossWin', 'tossDecision', 'note', 'endTimestamp', 'startTimestamp', 'slug', 'periods', 'finalResultOnly', 'feedLocked', 'cricketBallProperties', 'fanRatingEvent', 'showTotoPromo', 'isEditor'])

# %%
data['event']['cricketBallProperties']
# Out:
# ['time',
#  'number',
#  'over',
#  'ball',
#  'runs',
#  'score',
#  'scored',
#  'wicket',
#  'missed',
#  'incidentClassLabel',
#  'incidentClassColor',
#  'batsman',
#  'bowler',
#  'commentary',
#  'id',
#  'ballDetails',
#  'zone',
#  'angle',
#  'bowlDetail',
#  'fielder']
